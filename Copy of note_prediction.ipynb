# %% [markdown]
# # Preproccesing

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder
import time
from sklearn.model_selection import train_test_split
from tensorflow import keras

# %%
# !gdown  1TVmI7nhTLjdd_6ghEcjLp_9wW0HWi2oa

# %%
# ! unzip '/content/FinalProjectMat.zip'

# %%
print('artifacts')
print(len(os.listdir('artifacts')))
print('piano_pieces')
print(len(os.listdir('piano_pieces')))
print('piano_triads')
print(len(os.listdir('piano_triads')))
# Out:
# artifacts
# 40
# piano_pieces
# 400
# piano_triads
# 432

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.io.wavfile import read
from scipy import signal
from IPython.display import Audio, Image
from PIL import Image, ImageDraw
import librosa
import librosa.display
import pylab
from numpy.fft import fft, ifft
# %matplotlib inline
import math

# %%
songs = os.listdir('piano_pieces')

# %%
#split notes names in 4
def get_split(input):
  splited = np.char.split(input, sep ='_')
  splited = list(splited)
  splited = np.array(splited)
  return splited

# %%
def find_nth(haystack, needle, n):
    start = haystack.find(needle)
    while start >= 0 and n > 1:
        start = haystack.find(needle, start+len(needle))
        n -= 1
    return start

# %%
#load song.txt files in a list
songs_list = []
for song in songs:
  piece = np.loadtxt('piano_pieces/' + song, dtype=str)
  piece = piece[piece != '/']
  # temp = []
  # for note in piece:
  #   index = find_nth(note,"_",2)
  #   one = note[:index]
  #   two = note[index+1:]
  #   temp_note = [one,two[0],two[2]]
  #   temp.append(temp_note)
  songs_list.append(piece)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: loadtxt: Empty input file: "piano_pieces/Song1.txt"
#   after removing the cwd from sys.path.

# %%
len(songs_list)
# Out:
# 400

# %%
# temp_array = []
# new_list = []
# # temp = songs_list[0] + "_" + songs_list[1]
# # temp_array.append([temp, songs_list[2], songs_list[3]])
# for i in songs_list:
#   for j in i:
#     temp = j[0] + "_" + j[1]
#     temp_array.append([temp, j[2], j[3]])
#   new_list.append(temp_array)

# %%
#from length 3 to 30 add notes to X and the following note to y
X = []
y = []
sample_length =15
for song in songs_list:
  for i in range(0,len(song)-sample_length): # go through each song and get x and y
    temp = song[i:i + sample_length]
    X.append(temp)
    y.append(song[i+sample_length])

# %%
data_length =len(X)

# %%
X = np.array(X)

# %%
y = np.array(y)

# %%
X.shape
# Out:
# (31325, 15)

# %%
y.shape
# Out:
# (31325,)

# %%
y[0:10]
# Out:
# array(['G_maj_4_0', 'Bb_maj_2_0', 'Eb_maj_5_1', 'D_min_5_1', 'E_dim_5_1',
#        'A_maj_7_1', 'D_min_4_0', 'G_maj_4_0', 'Bb_maj_6_1', 'E_dim_5_0'],
#       dtype='<U10')

# %%
from sklearn.utils import shuffle



X, y = shuffle(X, y)
print(X[0])
print(y[0])
# Out:
# ['G_maj_5_0' 'Fs_maj_6_0' 'B_maj_3_0' 'E_maj_4_0' 'A_maj_2_1' 'E_maj_7_0'
#  'Fs_min_7_1' 'E_maj_2_1' 'A_maj_3_0' 'Eb_dim_6_0' 'D_maj_5_0' 'A_maj_2_1'
#  'E_maj_5_1' 'Fs_min_2_0' 'Cs_min_2_0']
# A_maj_4_0

# %%
def OH_encoder(data):
  values = np.array(data)
  label_encoder = LabelEncoder()
  integer_encoded = label_encoder.fit_transform(values)
  # onehot_encoder = OneHotEncoder(sparse=False)
  # integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
  # onehot_encoded = onehot_encoder.fit_transform(integer_encoded)
  return integer_encoded

# %%
temp_X = X.reshape(data_length*sample_length,)
print(temp_X.shape)
# Out:
# (469875,)

# %%
temp_concat = np.concatenate((temp_X,y),axis=0)

# %%
output1 = OH_encoder(temp_concat)

# %%
output_X = output1[0:data_length*sample_length].reshape(data_length, sample_length)

# %%
X = output_X

# %%
y = output1[data_length*sample_length:]

# %%
X = X.astype(int)
y = y.astype(int)

# %%
from keras import Sequential
from keras.layers import LSTM,Dropout,Dense,Activation, Flatten, Embedding, Conv1D, MaxPool1D, GlobalMaxPool1D, Input

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
def OH_encoder(data):
  values = np.array(data)
  label_encoder = LabelEncoder()
  integer_encoded = label_encoder.fit_transform(values)
  onehot_encoder = OneHotEncoder(sparse=False)
  integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
  onehot_encoded = onehot_encoder.fit_transform(integer_encoded)
  return onehot_encoded

# %%
# print(y[:,0])
# print(y[:,1])
# print(y[:,2])
# print(y[0])

# %%
# one hot the chord,octave and position
output1 = OH_encoder(y)
# output2 = OH_encoder(y[:,1])
# output3 = OH_encoder(y[:,2])

# %%
print(output1.shape)
# print(output2.shape)
# print(output3.shape)
# Out:
# (31325, 432)

# %%
X[0]
# Out:
# array([378, 344,  50, 232,  13, 238, 359, 229,  14, 260, 198,  13, 235,
#        348, 168])

# %%
# max_first =np.max(X[:,0])
# max_second =np.max(X[:,1])
# max_third =np.max(X[:,2])
# # print(max_second)
# # X[:,0]=X[:,0]/max_first

# %%
# X_scaled =X

# %%
# print(X[:,1]/2)

# %%
from keras.models import Model
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, BatchNormalization, Dropout, MaxPooling2D, AveragePooling2D
from keras.regularizers import l2
from keras.layers import LeakyReLU

# %% [markdown]
# # Training

# %%
# def branch_one(inputs, num, name):
#     x = LSTM(32, input_shape=(None,3), return_sequences=True)(inputs)
#     x = LSTM(32)(x)
#     x = Dense(64)(x)
#     x = BatchNormalization()(x)
#     x = Activation('relu')(x)
#     x = Dense(num)(x)
#     x = Activation("softmax", name=name)(x)
#     return x

def branch_one(inputs, num, name):
    x = LSTM(128, input_shape=(None,1), return_sequences=True)(inputs)
    x = LSTM(128)(x)
    x = Dense(256)(x)
    x=LeakyReLU(alpha=0.05)(x)
    x = Activation('relu')(x)
    x = Dense(num)(x)
    x = Activation("softmax", name=name)(x)
    return x
        
def branch_two(inputs, num, name):
    x = LSTM(64, input_shape=(None,3), return_sequences=True)(inputs)
    x = LSTM(128, return_sequences=False)(inputs)

    x = Dense(num, activation="softmax", name=name)(x)
    #x = Activation("softmax", name=name)(x)
    return x

def branch_three(inputs, num, name):
    x = LSTM(32, input_shape=(None,3), return_sequences=True)(inputs)
    x = LSTM(128)(x)
    x=Dropout(0.3)(x)
    x = Dense(256)(x)
    x=LeakyReLU(alpha=0.05)(x)
    #x=Dropout(0.3)(x)
    x = Dense(num)(x)
    x = Activation("softmax", name=name)(x)
    #x = Activation("softmax", name=name)(x)
    return x

input_shape = (sample_length,1)
inputs = Input(shape=input_shape)

one = branch_one(inputs, output1.shape[1], 'chord')
# two = branch_two(inputs, output2.shape[1], 'octave')
# three = branch_three(inputs, output3.shape[1], 'position')
model = Model(inputs=inputs,
            outputs =one)

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
# type(output1[0][0])
# type(y[0][0])

# %%
model.compile(optimizer=keras.optimizers.Adam(0.001),
                         
              loss={
                  'chord': 'categorical_crossentropy', 
              }
              ,metrics={
                  'chord': 'accuracy', 
              #     'octave': 'accuracy',
              #     'position': 'accuracy',
                  }
              )

# %%
# history = model.fit(X_scaled[0:10000],[output1[0:10000],output2[0:10000],output3[0:10000]],
#                     epochs=50,
#                     validation_split=0.33,
#                      batch_size = 64,
#                     shuffle=True,
#                     verbose=0,
#                     ) 

history = model.fit(X,output1,
                    epochs=100,
                    validation_split=0.2,
                     batch_size = 256,
                    shuffle=True,
                    )
# Out:
# Epoch 1/100
# 98/98 [==============================] - 5s 18ms/step - loss: 5.9109 - accuracy: 0.0046 - val_loss: 5.8626 - val_accuracy: 0.0048
# Epoch 2/100
# 98/98 [==============================] - 1s 9ms/step - loss: 5.8111 - accuracy: 0.0073 - val_loss: 5.7821 - val_accuracy: 0.0067
# Epoch 3/100
# 98/98 [==============================] - 1s 9ms/step - loss: 5.7594 - accuracy: 0.0078 - val_loss: 5.7655 - val_accuracy: 0.0093
# Epoch 4/100
# 98/98 [==============================] - 1s 9ms/step - loss: 5.7271 - accuracy: 0.0094 - val_loss: 5.7447 - val_accuracy: 0.0094
# Epoch 5/100
# 98/98 [==============================] - 1s 9ms/step - loss: 5.6842 - accuracy: 0.0093 - val_loss: 5.7323 - val_accuracy: 0.0099
# Epoch 6/100
# 98/98 [==============================] - 1s 9ms/step - loss: 5.6399 - accuracy: 0.0119 - val_loss: 5.7129 - val_accuracy: 0.0105
# Epoch 7/100
# 98/98 [==============================] - 1s 10ms/step - loss: 5.5909 - accuracy: 0.0135 - val_loss: 5.7035 - val_accuracy: 0.0115
# Epoch 8/100
# 98/98 [==============================] - 1s 9ms/step - loss: 5.5461 - accuracy: 0.0158 - val_loss: 5.7115 - val_accuracy: 0.0104
# Epoch 9/100
# 98/98 [==============================] - 1s 9ms/step - loss: 5.4998 - accuracy: 0.0163 - val_loss: 5.7264 - val_accuracy: 0.0104
# Epoch 10/100
# 98/98 [==============================] - 1s 9ms/step - loss: 5.4558 - accuracy: 0.0186 - val_loss: 5.7410 - val_accuracy: 0.0125
# Epoch 11/100
# 98/98 [==============================] - 1s 10ms/step - loss: 5.4097 - accuracy: 0.0197 - val_loss: 5.7663 - val_accuracy: 0.0117
# Epoch 12/100
# 98/98 [==============================] - 1s 10ms/step - loss: 5.3616 - accuracy: 0.0241 - val_loss: 5.7966 - val_accuracy: 0.0113
# Epoch 13/100
# 98/98 [==============================] - 1s 9ms/step - loss: 5.3047 - accuracy: 0.0260 - val_loss: 5.8326 - val_accuracy: 0.0118
# Epoch 14/100
# 98/98 [==============================] - 1s 9ms/step - loss: 5.2455 - accuracy: 0.0298 - val_loss: 5.8615 - val_accuracy: 0.0115
# Epoch 15/100
# 98/98 [==============================] - 1s 9ms/step - loss: 5.1824 - accuracy: 0.0326 - val_loss: 5.9027 - val_accuracy: 0.0107
# Epoch 16/100
# 98/98 [==============================] - 1s 9ms/step - loss: 5.1141 - accuracy: 0.0376 - val_loss: 5.9523 - val_accuracy: 0.0139
# Epoch 17/100
# 98/98 [==============================] - 1s 9ms/step - loss: 5.0478 - accuracy: 0.0415 - val_loss: 5.9979 - val_accuracy: 0.0137
# Epoch 18/100
# 98/98 [==============================] - 1s 9ms/step - loss: 4.9769 - accuracy: 0.0467 - val_loss: 6.0553 - val_accuracy: 0.0112
# Epoch 19/100
# 98/98 [==============================] - 1s 9ms/step - loss: 4.9076 - accuracy: 0.0536 - val_loss: 6.1204 - val_accuracy: 0.0123
# Epoch 20/100
# 98/98 [==============================] - 1s 9ms/step - loss: 4.8369 - accuracy: 0.0579 - val_loss: 6.1643 - val_accuracy: 0.0118
# Epoch 21/100
# 98/98 [==============================] - 1s 9ms/step - loss: 4.7613 - accuracy: 0.0656 - val_loss: 6.2405 - val_accuracy: 0.0115
# Epoch 22/100
# 98/98 [==============================] - 1s 10ms/step - loss: 4.6882 - accuracy: 0.0731 - val_loss: 6.2893 - val_accuracy: 0.0123
# Epoch 23/100
# 98/98 [==============================] - 1s 10ms/step - loss: 4.6118 - accuracy: 0.0836 - val_loss: 6.3539 - val_accuracy: 0.0107
# Epoch 24/100
# 98/98 [==============================] - 1s 9ms/step - loss: 4.5378 - accuracy: 0.0907 - val_loss: 6.4105 - val_accuracy: 0.0118
# Epoch 25/100
# 98/98 [==============================] - 1s 9ms/step - loss: 4.4646 - accuracy: 0.1007 - val_loss: 6.4988 - val_accuracy: 0.0109
# Epoch 26/100
# 98/98 [==============================] - 1s 9ms/step - loss: 4.3860 - accuracy: 0.1107 - val_loss: 6.5538 - val_accuracy: 0.0123
# Epoch 27/100
# 98/98 [==============================] - 1s 9ms/step - loss: 4.3119 - accuracy: 0.1189 - val_loss: 6.6593 - val_accuracy: 0.0110
# Epoch 28/100
# 98/98 [==============================] - 1s 9ms/step - loss: 4.2341 - accuracy: 0.1320 - val_loss: 6.7065 - val_accuracy: 0.0120
# Epoch 29/100
# 98/98 [==============================] - 1s 9ms/step - loss: 4.1524 - accuracy: 0.1423 - val_loss: 6.7657 - val_accuracy: 0.0112
# Epoch 30/100
# 98/98 [==============================] - 1s 10ms/step - loss: 4.0825 - accuracy: 0.1547 - val_loss: 6.8817 - val_accuracy: 0.0112
# Epoch 31/100
# 98/98 [==============================] - 1s 9ms/step - loss: 4.0024 - accuracy: 0.1668 - val_loss: 6.9726 - val_accuracy: 0.0118
# Epoch 32/100
# 98/98 [==============================] - 1s 9ms/step - loss: 3.9313 - accuracy: 0.1754 - val_loss: 7.0266 - val_accuracy: 0.0113
# Epoch 33/100
# 98/98 [==============================] - 1s 9ms/step - loss: 3.8530 - accuracy: 0.1885 - val_loss: 7.1598 - val_accuracy: 0.0094
# Epoch 34/100
# 98/98 [==============================] - 1s 9ms/step - loss: 3.7820 - accuracy: 0.2000 - val_loss: 7.2127 - val_accuracy: 0.0104
# Epoch 35/100
# 98/98 [==============================] - 1s 10ms/step - loss: 3.7107 - accuracy: 0.2133 - val_loss: 7.2941 - val_accuracy: 0.0109
# Epoch 36/100
# 98/98 [==============================] - 1s 9ms/step - loss: 3.6345 - accuracy: 0.2242 - val_loss: 7.4007 - val_accuracy: 0.0113
# Epoch 37/100
# 98/98 [==============================] - 1s 9ms/step - loss: 3.5600 - accuracy: 0.2364 - val_loss: 7.4707 - val_accuracy: 0.0105
# Epoch 38/100
# 98/98 [==============================] - 1s 12ms/step - loss: 3.4986 - accuracy: 0.2487 - val_loss: 7.5641 - val_accuracy: 0.0093
# Epoch 39/100
# 98/98 [==============================] - 1s 11ms/step - loss: 3.4151 - accuracy: 0.2640 - val_loss: 7.6352 - val_accuracy: 0.0110
# Epoch 40/100
# 98/98 [==============================] - 1s 9ms/step - loss: 3.3502 - accuracy: 0.2739 - val_loss: 7.7671 - val_accuracy: 0.0094
# Epoch 41/100
# 98/98 [==============================] - 1s 9ms/step - loss: 3.2792 - accuracy: 0.2869 - val_loss: 7.8443 - val_accuracy: 0.0117
# Epoch 42/100
# 98/98 [==============================] - 1s 9ms/step - loss: 3.2144 - accuracy: 0.3024 - val_loss: 7.9357 - val_accuracy: 0.0121
# Epoch 43/100
# 98/98 [==============================] - 1s 9ms/step - loss: 3.1457 - accuracy: 0.3150 - val_loss: 8.0546 - val_accuracy: 0.0109
# Epoch 44/100
# 98/98 [==============================] - 1s 9ms/step - loss: 3.0805 - accuracy: 0.3308 - val_loss: 8.1087 - val_accuracy: 0.0104
# Epoch 45/100
# 98/98 [==============================] - 1s 9ms/step - loss: 3.0180 - accuracy: 0.3411 - val_loss: 8.2399 - val_accuracy: 0.0104
# Epoch 46/100
# 98/98 [==============================] - 1s 9ms/step - loss: 2.9528 - accuracy: 0.3548 - val_loss: 8.3334 - val_accuracy: 0.0089
# Epoch 47/100
# 98/98 [==============================] - 1s 9ms/step - loss: 2.8937 - accuracy: 0.3644 - val_loss: 8.4939 - val_accuracy: 0.0104
# Epoch 48/100
# 98/98 [==============================] - 1s 9ms/step - loss: 2.8340 - accuracy: 0.3799 - val_loss: 8.5170 - val_accuracy: 0.0118
# Epoch 49/100
# 98/98 [==============================] - 1s 9ms/step - loss: 2.7677 - accuracy: 0.3964 - val_loss: 8.6554 - val_accuracy: 0.0105
# Epoch 50/100
# 98/98 [==============================] - 1s 9ms/step - loss: 2.7097 - accuracy: 0.4067 - val_loss: 8.7456 - val_accuracy: 0.0104
# Epoch 51/100
# 98/98 [==============================] - 1s 10ms/step - loss: 2.6547 - accuracy: 0.4155 - val_loss: 8.7990 - val_accuracy: 0.0101
# Epoch 52/100
# 98/98 [==============================] - 1s 9ms/step - loss: 2.5923 - accuracy: 0.4299 - val_loss: 8.9404 - val_accuracy: 0.0093
# Epoch 53/100
# 98/98 [==============================] - 1s 10ms/step - loss: 2.5409 - accuracy: 0.4433 - val_loss: 9.0333 - val_accuracy: 0.0097
# Epoch 54/100
# 98/98 [==============================] - 1s 10ms/step - loss: 2.4850 - accuracy: 0.4547 - val_loss: 9.1769 - val_accuracy: 0.0107
# Epoch 55/100
# 98/98 [==============================] - 1s 9ms/step - loss: 2.4287 - accuracy: 0.4664 - val_loss: 9.2221 - val_accuracy: 0.0093
# Epoch 56/100
# 98/98 [==============================] - 1s 9ms/step - loss: 2.3697 - accuracy: 0.4810 - val_loss: 9.3585 - val_accuracy: 0.0097
# Epoch 57/100
# 98/98 [==============================] - 1s 9ms/step - loss: 2.3161 - accuracy: 0.4959 - val_loss: 9.4797 - val_accuracy: 0.0094
# Epoch 58/100
# 98/98 [==============================] - 1s 10ms/step - loss: 2.2716 - accuracy: 0.5055 - val_loss: 9.5851 - val_accuracy: 0.0102
# Epoch 59/100
# 98/98 [==============================] - 1s 9ms/step - loss: 2.2206 - accuracy: 0.5130 - val_loss: 9.6899 - val_accuracy: 0.0091
# Epoch 60/100
# 98/98 [==============================] - 1s 9ms/step - loss: 2.1651 - accuracy: 0.5296 - val_loss: 9.7939 - val_accuracy: 0.0097
# Epoch 61/100
# 98/98 [==============================] - 1s 9ms/step - loss: 2.1195 - accuracy: 0.5361 - val_loss: 9.8940 - val_accuracy: 0.0088
# Epoch 62/100
# 98/98 [==============================] - 1s 10ms/step - loss: 2.0654 - accuracy: 0.5496 - val_loss: 10.0492 - val_accuracy: 0.0096
# Epoch 63/100
# 98/98 [==============================] - 1s 9ms/step - loss: 2.0222 - accuracy: 0.5592 - val_loss: 10.1490 - val_accuracy: 0.0101
# Epoch 64/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9788 - accuracy: 0.5698 - val_loss: 10.2669 - val_accuracy: 0.0089
# Epoch 65/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.9338 - accuracy: 0.5828 - val_loss: 10.3647 - val_accuracy: 0.0094
# Epoch 66/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.8877 - accuracy: 0.5918 - val_loss: 10.5061 - val_accuracy: 0.0088
# Epoch 67/100
# 98/98 [==============================] - 1s 10ms/step - loss: 1.8429 - accuracy: 0.6012 - val_loss: 10.6062 - val_accuracy: 0.0093
# Epoch 68/100
# 98/98 [==============================] - 1s 10ms/step - loss: 1.7997 - accuracy: 0.6119 - val_loss: 10.6593 - val_accuracy: 0.0093
# Epoch 69/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.7658 - accuracy: 0.6199 - val_loss: 10.8821 - val_accuracy: 0.0089
# Epoch 70/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.7240 - accuracy: 0.6280 - val_loss: 10.9148 - val_accuracy: 0.0091
# Epoch 71/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.6752 - accuracy: 0.6403 - val_loss: 11.0528 - val_accuracy: 0.0096
# Epoch 72/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.6445 - accuracy: 0.6507 - val_loss: 11.1699 - val_accuracy: 0.0080
# Epoch 73/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.6068 - accuracy: 0.6545 - val_loss: 11.2877 - val_accuracy: 0.0101
# Epoch 74/100
# 98/98 [==============================] - 1s 10ms/step - loss: 1.5685 - accuracy: 0.6664 - val_loss: 11.3723 - val_accuracy: 0.0093
# Epoch 75/100
# 98/98 [==============================] - 1s 10ms/step - loss: 1.5323 - accuracy: 0.6754 - val_loss: 11.5445 - val_accuracy: 0.0086
# Epoch 76/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.4846 - accuracy: 0.6850 - val_loss: 11.6773 - val_accuracy: 0.0093
# Epoch 77/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.4574 - accuracy: 0.6936 - val_loss: 11.7991 - val_accuracy: 0.0088
# Epoch 78/100
# 98/98 [==============================] - 1s 14ms/step - loss: 1.4144 - accuracy: 0.7014 - val_loss: 11.8778 - val_accuracy: 0.0096
# Epoch 79/100
# 98/98 [==============================] - 1s 13ms/step - loss: 1.3859 - accuracy: 0.7133 - val_loss: 11.9451 - val_accuracy: 0.0096
# Epoch 80/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.3577 - accuracy: 0.7179 - val_loss: 12.1708 - val_accuracy: 0.0091
# Epoch 81/100
# 98/98 [==============================] - 1s 10ms/step - loss: 1.3222 - accuracy: 0.7255 - val_loss: 12.2831 - val_accuracy: 0.0083
# Epoch 82/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.2932 - accuracy: 0.7326 - val_loss: 12.3863 - val_accuracy: 0.0081
# Epoch 83/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.2571 - accuracy: 0.7425 - val_loss: 12.4688 - val_accuracy: 0.0093
# Epoch 84/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.2301 - accuracy: 0.7478 - val_loss: 12.5962 - val_accuracy: 0.0089
# Epoch 85/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.1923 - accuracy: 0.7568 - val_loss: 12.7427 - val_accuracy: 0.0086
# Epoch 86/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.1652 - accuracy: 0.7653 - val_loss: 12.8663 - val_accuracy: 0.0104
# Epoch 87/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.1368 - accuracy: 0.7704 - val_loss: 12.9472 - val_accuracy: 0.0096
# Epoch 88/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.1049 - accuracy: 0.7772 - val_loss: 13.1852 - val_accuracy: 0.0096
# Epoch 89/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.0799 - accuracy: 0.7840 - val_loss: 13.2760 - val_accuracy: 0.0101
# Epoch 90/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.0565 - accuracy: 0.7907 - val_loss: 13.3778 - val_accuracy: 0.0091
# Epoch 91/100
# 98/98 [==============================] - 1s 10ms/step - loss: 1.0213 - accuracy: 0.7994 - val_loss: 13.5101 - val_accuracy: 0.0097
# Epoch 92/100
# 98/98 [==============================] - 1s 9ms/step - loss: 1.0018 - accuracy: 0.8027 - val_loss: 13.6604 - val_accuracy: 0.0093
# Epoch 93/100
# 98/98 [==============================] - 1s 9ms/step - loss: 0.9809 - accuracy: 0.8062 - val_loss: 13.7693 - val_accuracy: 0.0096
# Epoch 94/100
# 98/98 [==============================] - 1s 9ms/step - loss: 0.9552 - accuracy: 0.8115 - val_loss: 13.8671 - val_accuracy: 0.0093
# Epoch 95/100
# 98/98 [==============================] - 1s 10ms/step - loss: 0.9332 - accuracy: 0.8185 - val_loss: 13.9670 - val_accuracy: 0.0088
# Epoch 96/100
# 98/98 [==============================] - 1s 9ms/step - loss: 0.9083 - accuracy: 0.8269 - val_loss: 14.1753 - val_accuracy: 0.0097
# Epoch 97/100
# 98/98 [==============================] - 1s 9ms/step - loss: 0.8793 - accuracy: 0.8332 - val_loss: 14.2745 - val_accuracy: 0.0088
# Epoch 98/100
# 98/98 [==============================] - 1s 9ms/step - loss: 0.8532 - accuracy: 0.8396 - val_loss: 14.3344 - val_accuracy: 0.0096
# Epoch 99/100
# 98/98 [==============================] - 1s 9ms/step - loss: 0.8313 - accuracy: 0.8415 - val_loss: 14.5240 - val_accuracy: 0.0091
# Epoch 100/100
# 98/98 [==============================] - 1s 9ms/step - loss: 0.8114 - accuracy: 0.8475 - val_loss: 14.6147 - val_accuracy: 0.0091

# %%
# _, accuracy = model.evaluate(X[0:100],[output1[0:100],output2[0:100],output3[0:100]])
# print('Accuracy of train set: %.2f' % (accuracy*100))

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#results=model.predict(X[:200])

# %%
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1) 
plt.plot(train_acc, label='Training', color = 'red')
plt.plot(val_acc, label='Validation', color = 'aqua')
plt.xlabel('Epochs')
plt.ylabel('position Accuracy')
plt.legend()

plt.subplot(1, 2, 2) 
plt.plot(train_loss, label='Training', color = 'red')
plt.plot(val_loss, label='Validation', color = 'aqua')
plt.xlabel('Epochs')
plt.ylabel('position Loss')
plt.legend()

# %%
# import matplotlib.pyplot as plt
# #==============Chord================
# train_acc = history.history['chord_accuracy']
# train_loss = history.history['chord_loss']
# val_acc = history.history['val_chord_accuracy']
# val_loss = history.history['val_chord_loss']

# plt.figure(figsize=(12, 6))

# plt.subplot(1, 2, 1) 
# plt.plot(train_acc, label='Training', color = 'red')
# plt.plot(val_acc, label='Validation', color = 'aqua')
# plt.xlabel('Epochs')
# plt.ylabel('chord Accuracy')
# plt.legend()

# plt.subplot(1, 2, 2) 
# plt.plot(train_loss, label='Training', color = 'red')
# plt.plot(val_loss, label='Validation', color = 'aqua')
# plt.xlabel('Epochs')
# plt.ylabel('chord Loss')
# plt.legend()

# #==============octave================
# train_acc = history.history['octave_accuracy']
# train_loss = history.history['octave_loss']
# val_acc = history.history['val_octave_accuracy']
# val_loss = history.history['val_octave_loss']

# plt.figure(figsize=(12, 6))

# plt.subplot(1, 2, 1) 
# plt.plot(train_acc, label='Training', color = 'red')
# plt.plot(val_acc, label='Validation', color = 'aqua')
# plt.xlabel('Epochs')
# plt.ylabel('octave Accuracy')
# plt.legend()

# plt.subplot(1, 2, 2) 
# plt.plot(train_loss, label='Training', color = 'red')
# plt.plot(val_loss, label='Validation', color = 'aqua')
# plt.xlabel('Epochs')
# plt.ylabel('octave Loss')
# plt.legend()
# #==============position================
# train_acc = history.history['position_accuracy']
# train_loss = history.history['position_loss']
# val_acc = history.history['val_position_accuracy']
# val_loss = history.history['val_position_loss']

# plt.figure(figsize=(12, 6))

# plt.subplot(1, 2, 1) 
# plt.plot(train_acc, label='Training', color = 'red')
# plt.plot(val_acc, label='Validation', color = 'aqua')
# plt.xlabel('Epochs')
# plt.ylabel('position Accuracy')
# plt.legend()

# plt.subplot(1, 2, 2) 
# plt.plot(train_loss, label='Training', color = 'red')
# plt.plot(val_loss, label='Validation', color = 'aqua')
# plt.xlabel('Epochs')
# plt.ylabel('position Loss')
# plt.legend()

# %%
model.save('notePrediction.h5')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r "notePrediction.h5" "/content/drive/MyDrive/notePrediction.h5"
