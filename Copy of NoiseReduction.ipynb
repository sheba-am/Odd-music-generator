# %% [markdown]
# #Importing Libraries

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D,Conv1DTranspose,Concatenate,Input
import numpy as np
import IPython.display
import glob
from tqdm.notebook import tqdm
import librosa.display
import matplotlib.pyplot as plt

# %% [markdown]
# #Extracting Data

# %%
# !gdown --id 1kDXN8KqL2dvMqDt4q8kU7aI7NnJgnrTi
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1kDXN8KqL2dvMqDt4q8kU7aI7NnJgnrTi
# To: /content/datset.zip
# 100% 614M/614M [00:05<00:00, 110MB/s]

# %%
! unzip '/content/datset.zip'
# Out:
# Archive:  /content/datset.zip
#    creating: content/dataset/
#    creating: content/dataset/noisy_pieces/
#   inflating: content/dataset/noisy_pieces/noisy292.wav
#   inflating: content/dataset/noisy_pieces/noisy139.wav
#   inflating: content/dataset/noisy_pieces/noisy161.wav
#   inflating: content/dataset/noisy_pieces/noisy451.wav
#   inflating: content/dataset/noisy_pieces/noisy900.wav
#   inflating: content/dataset/noisy_pieces/noisy338.wav
#   inflating: content/dataset/noisy_pieces/noisy537.wav
#   inflating: content/dataset/noisy_pieces/noisy734.wav
#   inflating: content/dataset/noisy_pieces/noisy981.wav
#   inflating: content/dataset/noisy_pieces/noisy243.wav
#   inflating: content/dataset/noisy_pieces/noisy849.wav
#   inflating: content/dataset/noisy_pieces/noisy769.wav
#   inflating: content/dataset/noisy_pieces/noisy657.wav
#   inflating: content/dataset/noisy_pieces/noisy601.wav
#   inflating: content/dataset/noisy_pieces/noisy396.wav
#   inflating: content/dataset/noisy_pieces/noisy227.wav
#   inflating: content/dataset/noisy_pieces/noisy307.wav
#   inflating: content/dataset/noisy_pieces/noisy435.wav
#   inflating: content/dataset/noisy_pieces/noisy670.wav
#   inflating: content/dataset/noisy_pieces/noisy461.wav
#   inflating: content/dataset/noisy_pieces/noisy130.wav
#   inflating: content/dataset/noisy_pieces/noisy693.wav
#   inflating: content/dataset/noisy_pieces/noisy647.wav
#   inflating: content/dataset/noisy_pieces/noisy7.wav
#   inflating: content/dataset/noisy_pieces/noisy198.wav
#   inflating: content/dataset/noisy_pieces/noisy803.wav
#   inflating: content/dataset/noisy_pieces/noisy176.wav
#   inflating: content/dataset/noisy_pieces/noisy599.wav
#   inflating: content/dataset/noisy_pieces/noisy154.wav
#   inflating: content/dataset/noisy_pieces/noisy788.wav
#   inflating: content/dataset/noisy_pieces/noisy533.wav
#   inflating: content/dataset/noisy_pieces/noisy524.wav
#   inflating: content/dataset/noisy_pieces/noisy212.wav
#   inflating: content/dataset/noisy_pieces/noisy327.wav
#   inflating: content/dataset/noisy_pieces/noisy77.wav
#   inflating: content/dataset/noisy_pieces/noisy573.wav
#   inflating: content/dataset/noisy_pieces/noisy213.wav
#   inflating: content/dataset/noisy_pieces/noisy546.wav
#   inflating: content/dataset/noisy_pieces/noisy326.wav
#   inflating: content/dataset/noisy_pieces/noisy56.wav
#   inflating: content/dataset/noisy_pieces/noisy990.wav
#   inflating: content/dataset/noisy_pieces/noisy8.wav
#   inflating: content/dataset/noisy_pieces/noisy313.wav
#   inflating: content/dataset/noisy_pieces/noisy997.wav
#   inflating: content/dataset/noisy_pieces/noisy851.wav
#   inflating: content/dataset/noisy_pieces/noisy281.wav
#   inflating: content/dataset/noisy_pieces/noisy375.wav
#   inflating: content/dataset/noisy_pieces/noisy377.wav
#   inflating: content/dataset/noisy_pieces/noisy808.wav
#   inflating: content/dataset/noisy_pieces/noisy696.wav
#   inflating: content/dataset/noisy_pieces/noisy832.wav
#   inflating: content/dataset/noisy_pieces/noisy31.wav
#   inflating: content/dataset/noisy_pieces/noisy426.wav
#   inflating: content/dataset/noisy_pieces/noisy952.wav
#   inflating: content/dataset/noisy_pieces/noisy226.wav
#   inflating: content/dataset/noisy_pieces/noisy114.wav
#   inflating: content/dataset/noisy_pieces/noisy953.wav
#   inflating: content/dataset/noisy_pieces/noisy582.wav
#   inflating: content/dataset/noisy_pieces/noisy575.wav
#   inflating: content/dataset/noisy_pieces/noisy39.wav
#   inflating: content/dataset/noisy_pieces/noisy936.wav
#   inflating: content/dataset/noisy_pieces/noisy437.wav
#   inflating: content/dataset/noisy_pieces/noisy241.wav
#   inflating: content/dataset/noisy_pieces/noisy111.wav
#   inflating: content/dataset/noisy_pieces/noisy69.wav
#   inflating: content/dataset/noisy_pieces/noisy543.wav
#   inflating: content/dataset/noisy_pieces/noisy98.wav
#   inflating: content/dataset/noisy_pieces/noisy646.wav
#   inflating: content/dataset/noisy_pieces/noisy382.wav
#   inflating: content/dataset/noisy_pieces/noisy337.wav
#   inflating: content/dataset/noisy_pieces/noisy984.wav
#   inflating: content/dataset/noisy_pieces/noisy915.wav
#   inflating: content/dataset/noisy_pieces/noisy126.wav
#   inflating: content/dataset/noisy_pieces/noisy528.wav
#   inflating: content/dataset/noisy_pieces/noisy695.wav
#   inflating: content/dataset/noisy_pieces/noisy411.wav
#   inflating: content/dataset/noisy_pieces/noisy550.wav
#   inflating: content/dataset/noisy_pieces/noisy531.wav
#   inflating: content/dataset/noisy_pieces/noisy393.wav
#   inflating: content/dataset/noisy_pieces/noisy275.wav
#   inflating: content/dataset/noisy_pieces/noisy178.wav
#   inflating: content/dataset/noisy_pieces/noisy802.wav
#   inflating: content/dataset/noisy_pieces/noisy674.wav
#   inflating: content/dataset/noisy_pieces/noisy988.wav
#   inflating: content/dataset/noisy_pieces/noisy590.wav
#   inflating: content/dataset/noisy_pieces/noisy503.wav
#   inflating: content/dataset/noisy_pieces/noisy755.wav
#   inflating: content/dataset/noisy_pieces/noisy991.wav
#   inflating: content/dataset/noisy_pieces/noisy525.wav
#   inflating: content/dataset/noisy_pieces/noisy89.wav
#   inflating: content/dataset/noisy_pieces/noisy529.wav
#   inflating: content/dataset/noisy_pieces/noisy958.wav
#   inflating: content/dataset/noisy_pieces/noisy728.wav
#   inflating: content/dataset/noisy_pieces/noisy949.wav
#   inflating: content/dataset/noisy_pieces/noisy376.wav
#   inflating: content/dataset/noisy_pieces/noisy535.wav
#   inflating: content/dataset/noisy_pieces/noisy203.wav
#   inflating: content/dataset/noisy_pieces/noisy754.wav
#   inflating: content/dataset/noisy_pieces/noisy560.wav
#   inflating: content/dataset/noisy_pieces/noisy412.wav
#   inflating: content/dataset/noisy_pieces/noisy152.wav
#   inflating: content/dataset/noisy_pieces/noisy804.wav
#   inflating: content/dataset/noisy_pieces/noisy486.wav
#   inflating: content/dataset/noisy_pieces/noisy3.wav
#   inflating: content/dataset/noisy_pieces/noisy195.wav
#   inflating: content/dataset/noisy_pieces/noisy217.wav
#   inflating: content/dataset/noisy_pieces/noisy616.wav
#   inflating: content/dataset/noisy_pieces/noisy262.wav
#   inflating: content/dataset/noisy_pieces/noisy852.wav
#   inflating: content/dataset/noisy_pieces/noisy751.wav
#   inflating: content/dataset/noisy_pieces/noisy826.wav
#   inflating: content/dataset/noisy_pieces/noisy943.wav
#   inflating: content/dataset/noisy_pieces/noisy708.wav
#   inflating: content/dataset/noisy_pieces/noisy861.wav
#   inflating: content/dataset/noisy_pieces/noisy165.wav
#   inflating: content/dataset/noisy_pieces/noisy261.wav
#   inflating: content/dataset/noisy_pieces/noisy681.wav
#   inflating: content/dataset/noisy_pieces/noisy860.wav
#   inflating: content/dataset/noisy_pieces/noisy266.wav
#   inflating: content/dataset/noisy_pieces/noisy869.wav
#   inflating: content/dataset/noisy_pieces/noisy889.wav
#   inflating: content/dataset/noisy_pieces/noisy905.wav
#   inflating: content/dataset/noisy_pieces/noisy87.wav
#   inflating: content/dataset/noisy_pieces/noisy643.wav
#   inflating: content/dataset/noisy_pieces/noisy491.wav
#   inflating: content/dataset/noisy_pieces/noisy172.wav
#   inflating: content/dataset/noisy_pieces/noisy192.wav
#   inflating: content/dataset/noisy_pieces/noisy509.wav
#   inflating: content/dataset/noisy_pieces/noisy45.wav
#   inflating: content/dataset/noisy_pieces/noisy928.wav
#   inflating: content/dataset/noisy_pieces/noisy814.wav
#   inflating: content/dataset/noisy_pieces/noisy446.wav
#   inflating: content/dataset/noisy_pieces/noisy995.wav
#   inflating: content/dataset/noisy_pieces/noisy910.wav
#   inflating: content/dataset/noisy_pieces/noisy574.wav
#   inflating: content/dataset/noisy_pieces/noisy866.wav
#   inflating: content/dataset/noisy_pieces/noisy639.wav
#   inflating: content/dataset/noisy_pieces/noisy872.wav
#   inflating: content/dataset/noisy_pieces/noisy556.wav
#   inflating: content/dataset/noisy_pieces/noisy701.wav
#   inflating: content/dataset/noisy_pieces/noisy791.wav
#   inflating: content/dataset/noisy_pieces/noisy854.wav
#   inflating: content/dataset/noisy_pieces/noisy127.wav
#   inflating: content/dataset/noisy_pieces/noisy174.wav
#   inflating: content/dataset/noisy_pieces/noisy145.wav
#   inflating: content/dataset/noisy_pieces/noisy288.wav
#   inflating: content/dataset/noisy_pieces/noisy403.wav
#   inflating: content/dataset/noisy_pieces/noisy592.wav
#   inflating: content/dataset/noisy_pieces/noisy219.wav
#   inflating: content/dataset/noisy_pieces/noisy741.wav
#   inflating: content/dataset/noisy_pieces/noisy996.wav
#   inflating: content/dataset/noisy_pieces/noisy109.wav
#   inflating: content/dataset/noisy_pieces/noisy495.wav
#   inflating: content/dataset/noisy_pieces/noisy629.wav
#   inflating: content/dataset/noisy_pieces/noisy964.wav
#   inflating: content/dataset/noisy_pieces/noisy633.wav
#   inflating: content/dataset/noisy_pieces/noisy131.wav
#   inflating: content/dataset/noisy_pieces/noisy484.wav
#   inflating: content/dataset/noisy_pieces/noisy763.wav
#   inflating: content/dataset/noisy_pieces/noisy479.wav
#   inflating: content/dataset/noisy_pieces/noisy566.wav
#   inflating: content/dataset/noisy_pieces/noisy245.wav
#   inflating: content/dataset/noisy_pieces/noisy164.wav
#   inflating: content/dataset/noisy_pieces/noisy729.wav
#   inflating: content/dataset/noisy_pieces/noisy725.wav
#   inflating: content/dataset/noisy_pieces/noisy325.wav
#   inflating: content/dataset/noisy_pieces/noisy115.wav
#   inflating: content/dataset/noisy_pieces/noisy868.wav
#   inflating: content/dataset/noisy_pieces/noisy957.wav
#   inflating: content/dataset/noisy_pieces/noisy797.wav
#   inflating: content/dataset/noisy_pieces/noisy413.wav
#   inflating: content/dataset/noisy_pieces/noisy906.wav
#   inflating: content/dataset/noisy_pieces/noisy201.wav
#   inflating: content/dataset/noisy_pieces/noisy142.wav
#   inflating: content/dataset/noisy_pieces/noisy390.wav
#   inflating: content/dataset/noisy_pieces/noisy723.wav
#   inflating: content/dataset/noisy_pieces/noisy478.wav
#   inflating: content/dataset/noisy_pieces/noisy871.wav
#   inflating: content/dataset/noisy_pieces/noisy229.wav
#   inflating: content/dataset/noisy_pieces/noisy185.wav
#   inflating: content/dataset/noisy_pieces/noisy332.wav
#   inflating: content/dataset/noisy_pieces/noisy62.wav
#   inflating: content/dataset/noisy_pieces/noisy321.wav
#   inflating: content/dataset/noisy_pieces/noisy410.wav
#   inflating: content/dataset/noisy_pieces/noisy349.wav
#   inflating: content/dataset/noisy_pieces/noisy315.wav
#   inflating: content/dataset/noisy_pieces/noisy118.wav
#   inflating: content/dataset/noisy_pieces/noisy768.wav
#   inflating: content/dataset/noisy_pieces/noisy589.wav
#   inflating: content/dataset/noisy_pieces/noisy552.wav
#   inflating: content/dataset/noisy_pieces/noisy919.wav
#   inflating: content/dataset/noisy_pieces/noisy44.wav
#   inflating: content/dataset/noisy_pieces/noisy862.wav
#   inflating: content/dataset/noisy_pieces/noisy624.wav
#   inflating: content/dataset/noisy_pieces/noisy312.wav
#   inflating: content/dataset/noisy_pieces/noisy959.wav
#   inflating: content/dataset/noisy_pieces/noisy702.wav
#   inflating: content/dataset/noisy_pieces/noisy691.wav
#   inflating: content/dataset/noisy_pieces/noisy284.wav
#   inflating: content/dataset/noisy_pieces/noisy100.wav
#   inflating: content/dataset/noisy_pieces/noisy0.wav
#   inflating: content/dataset/noisy_pieces/noisy105.wav
#   inflating: content/dataset/noisy_pieces/noisy747.wav
#   inflating: content/dataset/noisy_pieces/noisy103.wav
#   inflating: content/dataset/noisy_pieces/noisy79.wav
#   inflating: content/dataset/noisy_pieces/noisy946.wav
#   inflating: content/dataset/noisy_pieces/noisy493.wav
#   inflating: content/dataset/noisy_pieces/noisy858.wav
#   inflating: content/dataset/noisy_pieces/noisy199.wav
#   inflating: content/dataset/noisy_pieces/noisy890.wav
#   inflating: content/dataset/noisy_pieces/noisy46.wav
#   inflating: content/dataset/noisy_pieces/noisy519.wav
#   inflating: content/dataset/noisy_pieces/noisy149.wav
#   inflating: content/dataset/noisy_pieces/noisy917.wav
#   inflating: content/dataset/noisy_pieces/noisy208.wav
#   inflating: content/dataset/noisy_pieces/noisy963.wav
#   inflating: content/dataset/noisy_pieces/noisy716.wav
#   inflating: content/dataset/noisy_pieces/noisy348.wav
#   inflating: content/dataset/noisy_pieces/noisy360.wav
#   inflating: content/dataset/noisy_pieces/noisy839.wav
#   inflating: content/dataset/noisy_pieces/noisy669.wav
#   inflating: content/dataset/noisy_pieces/noisy415.wav
#   inflating: content/dataset/noisy_pieces/noisy676.wav
#   inflating: content/dataset/noisy_pieces/noisy513.wav
#   inflating: content/dataset/noisy_pieces/noisy106.wav
#   inflating: content/dataset/noisy_pieces/noisy171.wav
#   inflating: content/dataset/noisy_pieces/noisy836.wav
#   inflating: content/dataset/noisy_pieces/noisy260.wav
#   inflating: content/dataset/noisy_pieces/noisy837.wav
#   inflating: content/dataset/noisy_pieces/noisy421.wav
#   inflating: content/dataset/noisy_pieces/noisy333.wav
#   inflating: content/dataset/noisy_pieces/noisy449.wav
#   inflating: content/dataset/noisy_pieces/noisy252.wav
#   inflating: content/dataset/noisy_pieces/noisy389.wav
#   inflating: content/dataset/noisy_pieces/noisy659.wav
#   inflating: content/dataset/noisy_pieces/noisy594.wav
#   inflating: content/dataset/noisy_pieces/noisy626.wav
#   inflating: content/dataset/noisy_pieces/noisy467.wav
#   inflating: content/dataset/noisy_pieces/noisy709.wav
#   inflating: content/dataset/noisy_pieces/noisy88.wav
#   inflating: content/dataset/noisy_pieces/noisy842.wav
#   inflating: content/dataset/noisy_pieces/noisy779.wav
#   inflating: content/dataset/noisy_pieces/noisy295.wav
#   inflating: content/dataset/noisy_pieces/noisy137.wav
#   inflating: content/dataset/noisy_pieces/noisy644.wav
#   inflating: content/dataset/noisy_pieces/noisy730.wav
#   inflating: content/dataset/noisy_pieces/noisy434.wav
#   inflating: content/dataset/noisy_pieces/noisy182.wav
#   inflating: content/dataset/noisy_pieces/noisy685.wav
#   inflating: content/dataset/noisy_pieces/noisy205.wav
#   inflating: content/dataset/noisy_pieces/noisy853.wav
#   inflating: content/dataset/noisy_pieces/noisy775.wav
#   inflating: content/dataset/noisy_pieces/noisy458.wav
#   inflating: content/dataset/noisy_pieces/noisy892.wav
#   inflating: content/dataset/noisy_pieces/noisy625.wav
#   inflating: content/dataset/noisy_pieces/noisy363.wav
#   inflating: content/dataset/noisy_pieces/noisy817.wav
#   inflating: content/dataset/noisy_pieces/noisy121.wav
#   inflating: content/dataset/noisy_pieces/noisy91.wav
#   inflating: content/dataset/noisy_pieces/noisy40.wav
#   inflating: content/dataset/noisy_pieces/noisy92.wav
#   inflating: content/dataset/noisy_pieces/noisy267.wav
#   inflating: content/dataset/noisy_pieces/noisy939.wav
#   inflating: content/dataset/noisy_pieces/noisy968.wav
#   inflating: content/dataset/noisy_pieces/noisy772.wav
#   inflating: content/dataset/noisy_pieces/noisy684.wav
#   inflating: content/dataset/noisy_pieces/noisy464.wav
#   inflating: content/dataset/noisy_pieces/noisy22.wav
#   inflating: content/dataset/noisy_pieces/noisy656.wav
#   inflating: content/dataset/noisy_pieces/noisy704.wav
#   inflating: content/dataset/noisy_pieces/noisy306.wav
#   inflating: content/dataset/noisy_pieces/noisy359.wav
#   inflating: content/dataset/noisy_pieces/noisy520.wav
#   inflating: content/dataset/noisy_pieces/noisy829.wav
#   inflating: content/dataset/noisy_pieces/noisy667.wav
#   inflating: content/dataset/noisy_pieces/noisy197.wav
#   inflating: content/dataset/noisy_pieces/noisy235.wav
#   inflating: content/dataset/noisy_pieces/noisy316.wav
#   inflating: content/dataset/noisy_pieces/noisy35.wav
#   inflating: content/dataset/noisy_pieces/noisy328.wav
#   inflating: content/dataset/noisy_pieces/noisy580.wav
#   inflating: content/dataset/noisy_pieces/noisy355.wav
#   inflating: content/dataset/noisy_pieces/noisy855.wav
#   inflating: content/dataset/noisy_pieces/noisy63.wav
#   inflating: content/dataset/noisy_pieces/noisy94.wav
#   inflating: content/dataset/noisy_pieces/noisy843.wav
#   inflating: content/dataset/noisy_pieces/noisy366.wav
#   inflating: content/dataset/noisy_pieces/noisy169.wav
#   inflating: content/dataset/noisy_pieces/noisy285.wav
#   inflating: content/dataset/noisy_pieces/noisy870.wav
#   inflating: content/dataset/noisy_pieces/noisy253.wav
#   inflating: content/dataset/noisy_pieces/noisy372.wav
#   inflating: content/dataset/noisy_pieces/noisy758.wav
#   inflating: content/dataset/noisy_pieces/noisy177.wav
#   inflating: content/dataset/noisy_pieces/noisy752.wav
#   inflating: content/dataset/noisy_pieces/noisy650.wav
#   inflating: content/dataset/noisy_pieces/noisy278.wav
#   inflating: content/dataset/noisy_pieces/noisy921.wav
#   inflating: content/dataset/noisy_pieces/noisy386.wav
#   inflating: content/dataset/noisy_pieces/noisy287.wav
#   inflating: content/dataset/noisy_pieces/noisy796.wav
#   inflating: content/dataset/noisy_pieces/noisy59.wav
#   inflating: content/dataset/noisy_pieces/noisy297.wav
#   inflating: content/dataset/noisy_pieces/noisy827.wav
#   inflating: content/dataset/noisy_pieces/noisy694.wav
#   inflating: content/dataset/noisy_pieces/noisy67.wav
#   inflating: content/dataset/noisy_pieces/noisy710.wav
#   inflating: content/dataset/noisy_pieces/noisy223.wav
#   inflating: content/dataset/noisy_pieces/noisy562.wav
#   inflating: content/dataset/noisy_pieces/noisy14.wav
#   inflating: content/dataset/noisy_pieces/noisy117.wav
#   inflating: content/dataset/noisy_pieces/noisy274.wav
#   inflating: content/dataset/noisy_pieces/noisy897.wav
#   inflating: content/dataset/noisy_pieces/noisy811.wav
#   inflating: content/dataset/noisy_pieces/noisy705.wav
#   inflating: content/dataset/noisy_pieces/noisy206.wav
#   inflating: content/dataset/noisy_pieces/noisy323.wav
#   inflating: content/dataset/noisy_pieces/noisy184.wav
#   inflating: content/dataset/noisy_pieces/noisy380.wav
#   inflating: content/dataset/noisy_pieces/noisy454.wav
#   inflating: content/dataset/noisy_pieces/noisy270.wav
#   inflating: content/dataset/noisy_pieces/noisy559.wav
#   inflating: content/dataset/noisy_pieces/noisy357.wav
#   inflating: content/dataset/noisy_pieces/noisy378.wav
#   inflating: content/dataset/noisy_pieces/noisy707.wav
#   inflating: content/dataset/noisy_pieces/noisy304.wav
#   inflating: content/dataset/noisy_pieces/noisy600.wav
#   inflating: content/dataset/noisy_pieces/noisy335.wav
#   inflating: content/dataset/noisy_pieces/noisy423.wav
#   inflating: content/dataset/noisy_pieces/noisy408.wav
#   inflating: content/dataset/noisy_pieces/noisy973.wav
#   inflating: content/dataset/noisy_pieces/noisy699.wav
#   inflating: content/dataset/noisy_pieces/noisy30.wav
#   inflating: content/dataset/noisy_pieces/noisy924.wav
#   inflating: content/dataset/noisy_pieces/noisy743.wav
#   inflating: content/dataset/noisy_pieces/noisy468.wav
#   inflating: content/dataset/noisy_pieces/noisy86.wav
#   inflating: content/dataset/noisy_pieces/noisy309.wav
#   inflating: content/dataset/noisy_pieces/noisy945.wav
#   inflating: content/dataset/noisy_pieces/noisy920.wav
#   inflating: content/dataset/noisy_pieces/noisy881.wav
#   inflating: content/dataset/noisy_pieces/noisy979.wav
#   inflating: content/dataset/noisy_pieces/noisy614.wav
#   inflating: content/dataset/noisy_pieces/noisy391.wav
#   inflating: content/dataset/noisy_pieces/noisy877.wav
#   inflating: content/dataset/noisy_pieces/noisy255.wav
#   inflating: content/dataset/noisy_pieces/noisy846.wav
#   inflating: content/dataset/noisy_pieces/noisy777.wav
#   inflating: content/dataset/noisy_pieces/noisy679.wav
#   inflating: content/dataset/noisy_pieces/noisy147.wav
#   inflating: content/dataset/noisy_pieces/noisy859.wav
#   inflating: content/dataset/noisy_pieces/noisy823.wav
#   inflating: content/dataset/noisy_pieces/noisy838.wav
#   inflating: content/dataset/noisy_pieces/noisy713.wav
#   inflating: content/dataset/noisy_pieces/noisy80.wav
#   inflating: content/dataset/noisy_pieces/noisy807.wav
#   inflating: content/dataset/noisy_pieces/noisy242.wav
#   inflating: content/dataset/noisy_pieces/noisy168.wav
#   inflating: content/dataset/noisy_pieces/noisy345.wav
#   inflating: content/dataset/noisy_pieces/noisy634.wav
#   inflating: content/dataset/noisy_pieces/noisy99.wav
#   inflating: content/dataset/noisy_pieces/noisy202.wav
#   inflating: content/dataset/noisy_pieces/noisy425.wav
#   inflating: content/dataset/noisy_pieces/noisy608.wav
#   inflating: content/dataset/noisy_pieces/noisy974.wav
#   inflating: content/dataset/noisy_pieces/noisy544.wav
#   inflating: content/dataset/noisy_pieces/noisy992.wav
#   inflating: content/dataset/noisy_pieces/noisy179.wav
#   inflating: content/dataset/noisy_pieces/noisy651.wav
#   inflating: content/dataset/noisy_pieces/noisy15.wav
#   inflating: content/dataset/noisy_pieces/noisy744.wav
#   inflating: content/dataset/noisy_pieces/noisy438.wav
#   inflating: content/dataset/noisy_pieces/noisy141.wav
#   inflating: content/dataset/noisy_pieces/noisy356.wav
#   inflating: content/dataset/noisy_pieces/noisy955.wav
#   inflating: content/dataset/noisy_pieces/noisy10.wav
#   inflating: content/dataset/noisy_pieces/noisy85.wav
#   inflating: content/dataset/noisy_pieces/noisy200.wav
#   inflating: content/dataset/noisy_pieces/noisy887.wav
#   inflating: content/dataset/noisy_pieces/noisy18.wav
#   inflating: content/dataset/noisy_pieces/noisy237.wav
#   inflating: content/dataset/noisy_pieces/noisy233.wav
#   inflating: content/dataset/noisy_pieces/noisy508.wav
#   inflating: content/dataset/noisy_pieces/noisy726.wav
#   inflating: content/dataset/noisy_pieces/noisy632.wav
#   inflating: content/dataset/noisy_pieces/noisy927.wav
#   inflating: content/dataset/noisy_pieces/noisy894.wav
#   inflating: content/dataset/noisy_pieces/noisy430.wav
#   inflating: content/dataset/noisy_pieces/noisy416.wav
#   inflating: content/dataset/noisy_pieces/noisy534.wav
#   inflating: content/dataset/noisy_pieces/noisy334.wav
#   inflating: content/dataset/noisy_pieces/noisy545.wav
#   inflating: content/dataset/noisy_pieces/noisy805.wav
#   inflating: content/dataset/noisy_pieces/noisy439.wav
#   inflating: content/dataset/noisy_pieces/noisy500.wav
#   inflating: content/dataset/noisy_pieces/noisy767.wav
#   inflating: content/dataset/noisy_pieces/noisy57.wav
#   inflating: content/dataset/noisy_pieces/noisy159.wav
#   inflating: content/dataset/noisy_pieces/noisy557.wav
#   inflating: content/dataset/noisy_pieces/noisy49.wav
#   inflating: content/dataset/noisy_pieces/noisy472.wav
#   inflating: content/dataset/noisy_pieces/noisy271.wav
#   inflating: content/dataset/noisy_pieces/noisy448.wav
#   inflating: content/dataset/noisy_pieces/noisy682.wav
#   inflating: content/dataset/noisy_pieces/noisy254.wav
#   inflating: content/dataset/noisy_pieces/noisy128.wav
#   inflating: content/dataset/noisy_pieces/noisy518.wav
#   inflating: content/dataset/noisy_pieces/noisy132.wav
#   inflating: content/dataset/noisy_pieces/noisy975.wav
#   inflating: content/dataset/noisy_pieces/noisy627.wav
#   inflating: content/dataset/noisy_pieces/noisy452.wav
#   inflating: content/dataset/noisy_pieces/noisy983.wav
#   inflating: content/dataset/noisy_pieces/noisy602.wav
#   inflating: content/dataset/noisy_pieces/noisy760.wav
#   inflating: content/dataset/noisy_pieces/noisy876.wav
#   inflating: content/dataset/noisy_pieces/noisy318.wav
#   inflating: content/dataset/noisy_pieces/noisy966.wav
#   inflating: content/dataset/noisy_pieces/noisy322.wav
#   inflating: content/dataset/noisy_pieces/noisy28.wav
#   inflating: content/dataset/noisy_pieces/noisy442.wav
#   inflating: content/dataset/noisy_pieces/noisy66.wav
#   inflating: content/dataset/noisy_pieces/noisy398.wav
#   inflating: content/dataset/noisy_pieces/noisy343.wav
#   inflating: content/dataset/noisy_pieces/noisy801.wav
#   inflating: content/dataset/noisy_pieces/noisy737.wav
#   inflating: content/dataset/noisy_pieces/noisy81.wav
#   inflating: content/dataset/noisy_pieces/noisy512.wav
#   inflating: content/dataset/noisy_pieces/noisy610.wav
#   inflating: content/dataset/noisy_pieces/noisy499.wav
#   inflating: content/dataset/noisy_pieces/noisy954.wav
#   inflating: content/dataset/noisy_pieces/noisy711.wav
#   inflating: content/dataset/noisy_pieces/noisy640.wav
#   inflating: content/dataset/noisy_pieces/noisy5.wav
#   inflating: content/dataset/noisy_pieces/noisy789.wav
#   inflating: content/dataset/noisy_pieces/noisy774.wav
#   inflating: content/dataset/noisy_pieces/noisy689.wav
#   inflating: content/dataset/noisy_pieces/noisy618.wav
#   inflating: content/dataset/noisy_pieces/noisy189.wav
#   inflating: content/dataset/noisy_pieces/noisy586.wav
#   inflating: content/dataset/noisy_pieces/noisy597.wav
#   inflating: content/dataset/noisy_pieces/noisy863.wav
#   inflating: content/dataset/noisy_pieces/noisy25.wav
#   inflating: content/dataset/noisy_pieces/noisy19.wav
#   inflating: content/dataset/noisy_pieces/noisy712.wav
#   inflating: content/dataset/noisy_pieces/noisy68.wav
#   inflating: content/dataset/noisy_pieces/noisy102.wav
#   inflating: content/dataset/noisy_pieces/noisy324.wav
#   inflating: content/dataset/noisy_pieces/noisy766.wav
#   inflating: content/dataset/noisy_pieces/noisy269.wav
#   inflating: content/dataset/noisy_pieces/noisy388.wav
#   inflating: content/dataset/noisy_pieces/noisy902.wav
#   inflating: content/dataset/noisy_pieces/noisy615.wav
#   inflating: content/dataset/noisy_pieces/noisy156.wav
#   inflating: content/dataset/noisy_pieces/noisy50.wav
#   inflating: content/dataset/noisy_pieces/noisy593.wav
#   inflating: content/dataset/noisy_pieces/noisy865.wav
#   inflating: content/dataset/noisy_pieces/noisy736.wav
#   inflating: content/dataset/noisy_pieces/noisy903.wav
#   inflating: content/dataset/noisy_pieces/noisy558.wav
#   inflating: content/dataset/noisy_pieces/noisy186.wav
#   inflating: content/dataset/noisy_pieces/noisy193.wav
#   inflating: content/dataset/noisy_pieces/noisy136.wav
#   inflating: content/dataset/noisy_pieces/noisy289.wav
#   inflating: content/dataset/noisy_pieces/noisy998.wav
#   inflating: content/dataset/noisy_pieces/noisy799.wav
#   inflating: content/dataset/noisy_pieces/noisy809.wav
#   inflating: content/dataset/noisy_pieces/noisy4.wav
#   inflating: content/dataset/noisy_pieces/noisy527.wav
#   inflating: content/dataset/noisy_pieces/noisy733.wav
#   inflating: content/dataset/noisy_pieces/noisy794.wav
#   inflating: content/dataset/noisy_pieces/noisy90.wav
#   inflating: content/dataset/noisy_pieces/noisy58.wav
#   inflating: content/dataset/noisy_pieces/noisy604.wav
#   inflating: content/dataset/noisy_pieces/noisy635.wav
#   inflating: content/dataset/noisy_pieces/noisy210.wav
#   inflating: content/dataset/noisy_pieces/noisy770.wav
#   inflating: content/dataset/noisy_pieces/noisy207.wav
#   inflating: content/dataset/noisy_pieces/noisy475.wav
#   inflating: content/dataset/noisy_pieces/noisy841.wav
#   inflating: content/dataset/noisy_pieces/noisy302.wav
#   inflating: content/dataset/noisy_pieces/noisy220.wav
#   inflating: content/dataset/noisy_pieces/noisy658.wav
#   inflating: content/dataset/noisy_pieces/noisy52.wav
#   inflating: content/dataset/noisy_pieces/noisy655.wav
#   inflating: content/dataset/noisy_pieces/noisy911.wav
#   inflating: content/dataset/noisy_pieces/noisy308.wav
#   inflating: content/dataset/noisy_pieces/noisy16.wav
#   inflating: content/dataset/noisy_pieces/noisy623.wav
#   inflating: content/dataset/noisy_pieces/noisy341.wav
#   inflating: content/dataset/noisy_pieces/noisy61.wav
#   inflating: content/dataset/noisy_pieces/noisy749.wav
#   inflating: content/dataset/noisy_pieces/noisy384.wav
#   inflating: content/dataset/noisy_pieces/noisy630.wav
#   inflating: content/dataset/noisy_pieces/noisy140.wav
#   inflating: content/dataset/noisy_pieces/noisy143.wav
#   inflating: content/dataset/noisy_pieces/noisy933.wav
#   inflating: content/dataset/noisy_pieces/noisy482.wav
#   inflating: content/dataset/noisy_pieces/noisy301.wav
#   inflating: content/dataset/noisy_pieces/noisy579.wav
#   inflating: content/dataset/noisy_pieces/noisy882.wav
#   inflating: content/dataset/noisy_pieces/noisy427.wav
#   inflating: content/dataset/noisy_pieces/noisy856.wav
#   inflating: content/dataset/noisy_pieces/noisy352.wav
#   inflating: content/dataset/noisy_pieces/noisy303.wav
#   inflating: content/dataset/noisy_pieces/noisy280.wav
#   inflating: content/dataset/noisy_pieces/noisy522.wav
#   inflating: content/dataset/noisy_pieces/noisy367.wav
#   inflating: content/dataset/noisy_pieces/noisy339.wav
#   inflating: content/dataset/noisy_pieces/noisy895.wav
#   inflating: content/dataset/noisy_pieces/noisy554.wav
#   inflating: content/dataset/noisy_pieces/noisy798.wav
#   inflating: content/dataset/noisy_pieces/noisy577.wav
#   inflating: content/dataset/noisy_pieces/noisy885.wav
#   inflating: content/dataset/noisy_pieces/noisy538.wav
#   inflating: content/dataset/noisy_pieces/noisy523.wav
#   inflating: content/dataset/noisy_pieces/noisy516.wav
#   inflating: content/dataset/noisy_pieces/noisy761.wav
#   inflating: content/dataset/noisy_pieces/noisy715.wav
#   inflating: content/dataset/noisy_pieces/noisy225.wav
#   inflating: content/dataset/noisy_pieces/noisy249.wav
#   inflating: content/dataset/noisy_pieces/noisy471.wav
#   inflating: content/dataset/noisy_pieces/noisy414.wav
#   inflating: content/dataset/noisy_pieces/noisy762.wav
#   inflating: content/dataset/noisy_pieces/noisy638.wav
#   inflating: content/dataset/noisy_pieces/noisy956.wav
#   inflating: content/dataset/noisy_pieces/noisy216.wav
#   inflating: content/dataset/noisy_pieces/noisy264.wav
#   inflating: content/dataset/noisy_pieces/noisy551.wav
#   inflating: content/dataset/noisy_pieces/noisy666.wav
#   inflating: content/dataset/noisy_pieces/noisy609.wav
#   inflating: content/dataset/noisy_pieces/noisy95.wav
#   inflating: content/dataset/noisy_pieces/noisy75.wav
#   inflating: content/dataset/noisy_pieces/noisy941.wav
#   inflating: content/dataset/noisy_pieces/noisy532.wav
#   inflating: content/dataset/noisy_pieces/noisy258.wav
#   inflating: content/dataset/noisy_pieces/noisy948.wav
#   inflating: content/dataset/noisy_pieces/noisy912.wav
#   inflating: content/dataset/noisy_pieces/noisy660.wav
#   inflating: content/dataset/noisy_pieces/noisy757.wav
#   inflating: content/dataset/noisy_pieces/noisy36.wav
#   inflating: content/dataset/noisy_pieces/noisy828.wav
#   inflating: content/dataset/noisy_pieces/noisy731.wav
#   inflating: content/dataset/noisy_pieces/noisy773.wav
#   inflating: content/dataset/noisy_pieces/noisy365.wav
#   inflating: content/dataset/noisy_pieces/noisy899.wav
#   inflating: content/dataset/noisy_pieces/noisy248.wav
#   inflating: content/dataset/noisy_pieces/noisy55.wav
#   inflating: content/dataset/noisy_pieces/noisy259.wav
#   inflating: content/dataset/noisy_pieces/noisy612.wav
#   inflating: content/dataset/noisy_pieces/noisy222.wav
#   inflating: content/dataset/noisy_pieces/noisy166.wav
#   inflating: content/dataset/noisy_pieces/noisy29.wav
#   inflating: content/dataset/noisy_pieces/noisy238.wav
#   inflating: content/dataset/noisy_pieces/noisy675.wav
#   inflating: content/dataset/noisy_pieces/noisy231.wav
#   inflating: content/dataset/noisy_pieces/noisy23.wav
#   inflating: content/dataset/noisy_pieces/noisy48.wav
#   inflating: content/dataset/noisy_pieces/noisy290.wav
#   inflating: content/dataset/noisy_pieces/noisy497.wav
#   inflating: content/dataset/noisy_pieces/noisy221.wav
#   inflating: content/dataset/noisy_pieces/noisy967.wav
#   inflating: content/dataset/noisy_pieces/noisy698.wav
#   inflating: content/dataset/noisy_pieces/noisy268.wav
#   inflating: content/dataset/noisy_pieces/noisy815.wav
#   inflating: content/dataset/noisy_pieces/noisy436.wav
#   inflating: content/dataset/noisy_pieces/noisy273.wav
#   inflating: content/dataset/noisy_pieces/noisy314.wav
#   inflating: content/dataset/noisy_pieces/noisy756.wav
#   inflating: content/dataset/noisy_pieces/noisy570.wav
#   inflating: content/dataset/noisy_pieces/noisy409.wav
#   inflating: content/dataset/noisy_pieces/noisy722.wav
#   inflating: content/dataset/noisy_pieces/noisy930.wav
#   inflating: content/dataset/noisy_pieces/noisy129.wav
#   inflating: content/dataset/noisy_pieces/noisy38.wav
#   inflating: content/dataset/noisy_pieces/noisy848.wav
#   inflating: content/dataset/noisy_pieces/noisy800.wav
#   inflating: content/dataset/noisy_pieces/noisy73.wav
#   inflating: content/dataset/noisy_pieces/noisy329.wav
#   inflating: content/dataset/noisy_pieces/noisy891.wav
#   inflating: content/dataset/noisy_pieces/noisy194.wav
#   inflating: content/dataset/noisy_pieces/noisy942.wav
#   inflating: content/dataset/noisy_pieces/noisy251.wav
#   inflating: content/dataset/noisy_pieces/noisy155.wav
#   inflating: content/dataset/noisy_pieces/noisy834.wav
#   inflating: content/dataset/noisy_pieces/noisy652.wav
#   inflating: content/dataset/noisy_pieces/noisy714.wav
#   inflating: content/dataset/noisy_pieces/noisy239.wav
#   inflating: content/dataset/noisy_pieces/noisy831.wav
#   inflating: content/dataset/noisy_pieces/noisy167.wav
#   inflating: content/dataset/noisy_pieces/noisy793.wav
#   inflating: content/dataset/noisy_pieces/noisy83.wav
#   inflating: content/dataset/noisy_pieces/noisy970.wav
#   inflating: content/dataset/noisy_pieces/noisy224.wav
#   inflating: content/dataset/noisy_pieces/noisy424.wav
#   inflating: content/dataset/noisy_pieces/noisy244.wav
#   inflating: content/dataset/noisy_pieces/noisy463.wav
#   inflating: content/dataset/noisy_pieces/noisy934.wav
#   inflating: content/dataset/noisy_pieces/noisy125.wav
#   inflating: content/dataset/noisy_pieces/noisy907.wav
#   inflating: content/dataset/noisy_pieces/noisy53.wav
#   inflating: content/dataset/noisy_pieces/noisy874.wav
#   inflating: content/dataset/noisy_pieces/noisy925.wav
#   inflating: content/dataset/noisy_pieces/noisy569.wav
#   inflating: content/dataset/noisy_pieces/noisy680.wav
#   inflating: content/dataset/noisy_pieces/noisy133.wav
#   inflating: content/dataset/noisy_pieces/noisy880.wav
#   inflating: content/dataset/noisy_pieces/noisy163.wav
#   inflating: content/dataset/noisy_pieces/noisy564.wav
#   inflating: content/dataset/noisy_pieces/noisy703.wav
#   inflating: content/dataset/noisy_pieces/noisy864.wav
#   inflating: content/dataset/noisy_pieces/noisy792.wav
#   inflating: content/dataset/noisy_pieces/noisy336.wav
#   inflating: content/dataset/noisy_pieces/noisy34.wav
#   inflating: content/dataset/noisy_pieces/noisy477.wav
#   inflating: content/dataset/noisy_pieces/noisy394.wav
#   inflating: content/dataset/noisy_pieces/noisy654.wav
#   inflating: content/dataset/noisy_pieces/noisy72.wav
#   inflating: content/dataset/noisy_pieces/noisy294.wav
#   inflating: content/dataset/noisy_pieces/noisy27.wav
#   inflating: content/dataset/noisy_pieces/noisy104.wav
#   inflating: content/dataset/noisy_pieces/noisy835.wav
#   inflating: content/dataset/noisy_pieces/noisy387.wav
#   inflating: content/dataset/noisy_pieces/noisy972.wav
#   inflating: content/dataset/noisy_pieces/noisy989.wav
#   inflating: content/dataset/noisy_pieces/noisy417.wav
#   inflating: content/dataset/noisy_pieces/noisy993.wav
#   inflating: content/dataset/noisy_pieces/noisy488.wav
#   inflating: content/dataset/noisy_pieces/noisy742.wav
#   inflating: content/dataset/noisy_pieces/noisy969.wav
#   inflating: content/dataset/noisy_pieces/noisy211.wav
#   inflating: content/dataset/noisy_pieces/noisy576.wav
#   inflating: content/dataset/noisy_pieces/noisy686.wav
#   inflating: content/dataset/noisy_pieces/noisy719.wav
#   inflating: content/dataset/noisy_pieces/noisy662.wav
#   inflating: content/dataset/noisy_pieces/noisy346.wav
#   inflating: content/dataset/noisy_pieces/noisy636.wav
#   inflating: content/dataset/noisy_pieces/noisy745.wav
#   inflating: content/dataset/noisy_pieces/noisy816.wav
#   inflating: content/dataset/noisy_pieces/noisy485.wav
#   inflating: content/dataset/noisy_pieces/noisy256.wav
#   inflating: content/dataset/noisy_pieces/noisy819.wav
#   inflating: content/dataset/noisy_pieces/noisy447.wav
#   inflating: content/dataset/noisy_pieces/noisy883.wav
#   inflating: content/dataset/noisy_pieces/noisy965.wav
#   inflating: content/dataset/noisy_pieces/noisy257.wav
#   inflating: content/dataset/noisy_pieces/noisy581.wav
#   inflating: content/dataset/noisy_pieces/noisy361.wav
#   inflating: content/dataset/noisy_pieces/noisy476.wav
#   inflating: content/dataset/noisy_pieces/noisy923.wav
#   inflating: content/dataset/noisy_pieces/noisy42.wav
#   inflating: content/dataset/noisy_pieces/noisy771.wav
#   inflating: content/dataset/noisy_pieces/noisy82.wav
#   inflating: content/dataset/noisy_pieces/noisy502.wav
#   inflating: content/dataset/noisy_pieces/noisy60.wav
#   inflating: content/dataset/noisy_pieces/noisy795.wav
#   inflating: content/dataset/noisy_pieces/noisy20.wav
#   inflating: content/dataset/noisy_pieces/noisy753.wav
#   inflating: content/dataset/noisy_pieces/noisy135.wav
#   inflating: content/dataset/noisy_pieces/noisy74.wav
#   inflating: content/dataset/noisy_pieces/noisy385.wav
#   inflating: content/dataset/noisy_pieces/noisy300.wav
#   inflating: content/dataset/noisy_pieces/noisy565.wav
#   inflating: content/dataset/noisy_pieces/noisy215.wav
#   inflating: content/dataset/noisy_pieces/noisy272.wav
#   inflating: content/dataset/noisy_pieces/noisy157.wav
#   inflating: content/dataset/noisy_pieces/noisy247.wav
#   inflating: content/dataset/noisy_pieces/noisy234.wav
#   inflating: content/dataset/noisy_pieces/noisy578.wav
#   inflating: content/dataset/noisy_pieces/noisy572.wav
#   inflating: content/dataset/noisy_pieces/noisy962.wav
#   inflating: content/dataset/noisy_pieces/noisy541.wav
#   inflating: content/dataset/noisy_pieces/noisy124.wav
#   inflating: content/dataset/noisy_pieces/noisy561.wav
#   inflating: content/dataset/noisy_pieces/noisy645.wav
#   inflating: content/dataset/noisy_pieces/noisy690.wav
#   inflating: content/dataset/noisy_pieces/noisy455.wav
#   inflating: content/dataset/noisy_pieces/noisy628.wav
#   inflating: content/dataset/noisy_pieces/noisy549.wav
#   inflating: content/dataset/noisy_pieces/noisy622.wav
#   inflating: content/dataset/noisy_pieces/noisy305.wav
#   inflating: content/dataset/noisy_pieces/noisy344.wav
#   inflating: content/dataset/noisy_pieces/noisy470.wav
#   inflating: content/dataset/noisy_pieces/noisy209.wav
#   inflating: content/dataset/noisy_pieces/noisy293.wav
#   inflating: content/dataset/noisy_pieces/noisy908.wav
#   inflating: content/dataset/noisy_pieces/noisy517.wav
#   inflating: content/dataset/noisy_pieces/noisy931.wav
#   inflating: content/dataset/noisy_pieces/noisy595.wav
#   inflating: content/dataset/noisy_pieces/noisy700.wav
#   inflating: content/dataset/noisy_pieces/noisy84.wav
#   inflating: content/dataset/noisy_pieces/noisy820.wav
#   inflating: content/dataset/noisy_pieces/noisy999.wav
#   inflating: content/dataset/noisy_pieces/noisy381.wav
#   inflating: content/dataset/noisy_pieces/noisy746.wav
#   inflating: content/dataset/noisy_pieces/noisy6.wav
#   inflating: content/dataset/noisy_pieces/noisy228.wav
#   inflating: content/dataset/noisy_pieces/noisy926.wav
#   inflating: content/dataset/noisy_pieces/noisy606.wav
#   inflating: content/dataset/noisy_pieces/noisy12.wav
#   inflating: content/dataset/noisy_pieces/noisy196.wav
#   inflating: content/dataset/noisy_pieces/noisy370.wav
#   inflating: content/dataset/noisy_pieces/noisy721.wav
#   inflating: content/dataset/noisy_pieces/noisy65.wav
#   inflating: content/dataset/noisy_pieces/noisy922.wav
#   inflating: content/dataset/noisy_pieces/noisy588.wav
#   inflating: content/dataset/noisy_pieces/noisy369.wav
#   inflating: content/dataset/noisy_pieces/noisy514.wav
#   inflating: content/dataset/noisy_pieces/noisy395.wav
#   inflating: content/dataset/noisy_pieces/noisy776.wav
#   inflating: content/dataset/noisy_pieces/noisy350.wav
#   inflating: content/dataset/noisy_pieces/noisy498.wav
#   inflating: content/dataset/noisy_pieces/noisy553.wav
#   inflating: content/dataset/noisy_pieces/noisy428.wav
#   inflating: content/dataset/noisy_pieces/noisy683.wav
#   inflating: content/dataset/noisy_pieces/noisy120.wav
#   inflating: content/dataset/noisy_pieces/noisy379.wav
#   inflating: content/dataset/noisy_pieces/noisy648.wav
#   inflating: content/dataset/noisy_pieces/noisy170.wav
#   inflating: content/dataset/noisy_pieces/noisy510.wav
#   inflating: content/dataset/noisy_pieces/noisy977.wav
#   inflating: content/dataset/noisy_pieces/noisy596.wav
#   inflating: content/dataset/noisy_pieces/noisy778.wav
#   inflating: content/dataset/noisy_pieces/noisy265.wav
#   inflating: content/dataset/noisy_pieces/noisy982.wav
#   inflating: content/dataset/noisy_pieces/noisy153.wav
#   inflating: content/dataset/noisy_pieces/noisy918.wav
#   inflating: content/dataset/noisy_pieces/noisy462.wav
#   inflating: content/dataset/noisy_pieces/noisy748.wav
#   inflating: content/dataset/noisy_pieces/noisy490.wav
#   inflating: content/dataset/noisy_pieces/noisy617.wav
#   inflating: content/dataset/noisy_pieces/noisy929.wav
#   inflating: content/dataset/noisy_pieces/noisy400.wav
#   inflating: content/dataset/noisy_pieces/noisy750.wav
#   inflating: content/dataset/noisy_pieces/noisy473.wav
#   inflating: content/dataset/noisy_pieces/noisy833.wav
#   inflating: content/dataset/noisy_pieces/noisy879.wav
#   inflating: content/dataset/noisy_pieces/noisy505.wav
#   inflating: content/dataset/noisy_pieces/noisy296.wav
#   inflating: content/dataset/noisy_pieces/noisy971.wav
#   inflating: content/dataset/noisy_pieces/noisy530.wav
#   inflating: content/dataset/noisy_pieces/noisy619.wav
#   inflating: content/dataset/noisy_pieces/noisy786.wav
#   inflating: content/dataset/noisy_pieces/noisy663.wav
#   inflating: content/dataset/noisy_pieces/noisy41.wav
#   inflating: content/dataset/noisy_pieces/noisy878.wav
#   inflating: content/dataset/noisy_pieces/noisy397.wav
#   inflating: content/dataset/noisy_pieces/noisy496.wav
#   inflating: content/dataset/noisy_pieces/noisy319.wav
#   inflating: content/dataset/noisy_pieces/noisy330.wav
#   inflating: content/dataset/noisy_pieces/noisy909.wav
#   inflating: content/dataset/noisy_pieces/noisy664.wav
#   inflating: content/dataset/noisy_pieces/noisy940.wav
#   inflating: content/dataset/noisy_pieces/noisy898.wav
#   inflating: content/dataset/noisy_pieces/noisy481.wav
#   inflating: content/dataset/noisy_pieces/noisy867.wav
#   inflating: content/dataset/noisy_pieces/noisy759.wav
#   inflating: content/dataset/noisy_pieces/noisy17.wav
#   inflating: content/dataset/noisy_pieces/noisy781.wav
#   inflating: content/dataset/noisy_pieces/noisy845.wav
#   inflating: content/dataset/noisy_pieces/noisy914.wav
#   inflating: content/dataset/noisy_pieces/noisy204.wav
#   inflating: content/dataset/noisy_pieces/noisy320.wav
#   inflating: content/dataset/noisy_pieces/noisy504.wav
#   inflating: content/dataset/noisy_pieces/noisy738.wav
#   inflating: content/dataset/noisy_pieces/noisy980.wav
#   inflating: content/dataset/noisy_pieces/noisy501.wav
#   inflating: content/dataset/noisy_pieces/noisy71.wav
#   inflating: content/dataset/noisy_pieces/noisy697.wav
#   inflating: content/dataset/noisy_pieces/noisy483.wav
#   inflating: content/dataset/noisy_pieces/noisy460.wav
#   inflating: content/dataset/noisy_pieces/noisy110.wav
#   inflating: content/dataset/noisy_pieces/noisy540.wav
#   inflating: content/dataset/noisy_pieces/noisy282.wav
#   inflating: content/dataset/noisy_pieces/noisy847.wav
#   inflating: content/dataset/noisy_pieces/noisy585.wav
#   inflating: content/dataset/noisy_pieces/noisy364.wav
#   inflating: content/dataset/noisy_pieces/noisy453.wav
#   inflating: content/dataset/noisy_pieces/noisy764.wav
#   inflating: content/dataset/noisy_pieces/noisy938.wav
#   inflating: content/dataset/noisy_pieces/noisy263.wav
#   inflating: content/dataset/noisy_pieces/noisy373.wav
#   inflating: content/dataset/noisy_pieces/noisy101.wav
#   inflating: content/dataset/noisy_pieces/noisy457.wav
#   inflating: content/dataset/noisy_pieces/noisy571.wav
#   inflating: content/dataset/noisy_pieces/noisy688.wav
#   inflating: content/dataset/noisy_pieces/noisy950.wav
#   inflating: content/dataset/noisy_pieces/noisy960.wav
#   inflating: content/dataset/noisy_pieces/noisy765.wav
#   inflating: content/dataset/noisy_pieces/noisy961.wav
#   inflating: content/dataset/noisy_pieces/noisy563.wav
#   inflating: content/dataset/noisy_pieces/noisy138.wav
#   inflating: content/dataset/noisy_pieces/noisy465.wav
#   inflating: content/dataset/noisy_pieces/noisy187.wav
#   inflating: content/dataset/noisy_pieces/noisy985.wav
#   inflating: content/dataset/noisy_pieces/noisy418.wav
#   inflating: content/dataset/noisy_pieces/noisy76.wav
#   inflating: content/dataset/noisy_pieces/noisy976.wav
#   inflating: content/dataset/noisy_pieces/noisy291.wav
#   inflating: content/dataset/noisy_pieces/noisy122.wav
#   inflating: content/dataset/noisy_pieces/noisy740.wav
#   inflating: content/dataset/noisy_pieces/noisy181.wav
#   inflating: content/dataset/noisy_pieces/noisy445.wav
#   inflating: content/dataset/noisy_pieces/noisy21.wav
#   inflating: content/dataset/noisy_pieces/noisy459.wav
#   inflating: content/dataset/noisy_pieces/noisy951.wav
#   inflating: content/dataset/noisy_pieces/noisy13.wav
#   inflating: content/dataset/noisy_pieces/noisy456.wav
#   inflating: content/dataset/noisy_pieces/noisy494.wav
#   inflating: content/dataset/noisy_pieces/noisy317.wav
#   inflating: content/dataset/noisy_pieces/noisy901.wav
#   inflating: content/dataset/noisy_pieces/noisy661.wav
#   inflating: content/dataset/noisy_pieces/noisy250.wav
#   inflating: content/dataset/noisy_pieces/noisy932.wav
#   inflating: content/dataset/noisy_pieces/noisy536.wav
#   inflating: content/dataset/noisy_pieces/noisy402.wav
#   inflating: content/dataset/noisy_pieces/noisy603.wav
#   inflating: content/dataset/noisy_pieces/noisy432.wav
#   inflating: content/dataset/noisy_pieces/noisy620.wav
#   inflating: content/dataset/noisy_pieces/noisy873.wav
#   inflating: content/dataset/noisy_pieces/noisy466.wav
#   inflating: content/dataset/noisy_pieces/noisy668.wav
#   inflating: content/dataset/noisy_pieces/noisy368.wav
#   inflating: content/dataset/noisy_pieces/noisy474.wav
#   inflating: content/dataset/noisy_pieces/noisy605.wav
#   inflating: content/dataset/noisy_pieces/noisy511.wav
#   inflating: content/dataset/noisy_pieces/noisy362.wav
#   inflating: content/dataset/noisy_pieces/noisy113.wav
#   inflating: content/dataset/noisy_pieces/noisy526.wav
#   inflating: content/dataset/noisy_pieces/noisy162.wav
#   inflating: content/dataset/noisy_pieces/noisy419.wav
#   inflating: content/dataset/noisy_pieces/noisy43.wav
#   inflating: content/dataset/noisy_pieces/noisy555.wav
#   inflating: content/dataset/noisy_pieces/noisy407.wav
#   inflating: content/dataset/noisy_pieces/noisy158.wav
#   inflating: content/dataset/noisy_pieces/noisy383.wav
#   inflating: content/dataset/noisy_pieces/noisy450.wav
#   inflating: content/dataset/noisy_pieces/noisy813.wav
#   inflating: content/dataset/noisy_pieces/noisy568.wav
#   inflating: content/dataset/noisy_pieces/noisy916.wav
#   inflating: content/dataset/noisy_pieces/noisy134.wav
#   inflating: content/dataset/noisy_pieces/noisy150.wav
# ...
#   inflating: content/dataset/clean_pieces/clean769.wav
#   inflating: content/dataset/clean_pieces/clean851.wav
#   inflating: content/dataset/clean_pieces/clean511.wav
#   inflating: content/dataset/clean_pieces/clean650.wav
#   inflating: content/dataset/clean_pieces/clean580.wav
#   inflating: content/dataset/clean_pieces/clean859.wav
#   inflating: content/dataset/clean_pieces/clean596.wav
#   inflating: content/dataset/clean_pieces/clean100.wav
#   inflating: content/dataset/clean_pieces/clean425.wav
#   inflating: content/dataset/clean_pieces/clean545.wav
#   inflating: content/dataset/clean_pieces/clean237.wav
#   inflating: content/dataset/clean_pieces/clean143.wav
#   inflating: content/dataset/clean_pieces/clean181.wav
#   inflating: content/dataset/clean_pieces/clean342.wav
#   inflating: content/dataset/clean_pieces/clean75.wav
#   inflating: content/dataset/clean_pieces/clean581.wav
#   inflating: content/dataset/clean_pieces/clean149.wav
#   inflating: content/dataset/clean_pieces/clean474.wav
#   inflating: content/dataset/clean_pieces/clean22.wav
#   inflating: content/dataset/clean_pieces/clean166.wav
#   inflating: content/dataset/clean_pieces/clean458.wav
#   inflating: content/dataset/clean_pieces/clean764.wav
#   inflating: content/dataset/clean_pieces/clean671.wav
#   inflating: content/dataset/clean_pieces/clean244.wav
#   inflating: content/dataset/clean_pieces/clean898.wav
#   inflating: content/dataset/clean_pieces/clean737.wav
#   inflating: content/dataset/clean_pieces/clean743.wav
#   inflating: content/dataset/clean_pieces/clean866.wav
#   inflating: content/dataset/clean_pieces/clean180.wav
#   inflating: content/dataset/clean_pieces/clean682.wav
#   inflating: content/dataset/clean_pieces/clean171.wav
#   inflating: content/dataset/clean_pieces/clean522.wav
#   inflating: content/dataset/clean_pieces/clean365.wav
#   inflating: content/dataset/clean_pieces/clean311.wav
#   inflating: content/dataset/clean_pieces/clean489.wav
#   inflating: content/dataset/clean_pieces/clean886.wav
#   inflating: content/dataset/clean_pieces/clean861.wav
#   inflating: content/dataset/clean_pieces/clean849.wav
#   inflating: content/dataset/clean_pieces/clean571.wav
#   inflating: content/dataset/clean_pieces/clean271.wav
#   inflating: content/dataset/clean_pieces/clean575.wav
#   inflating: content/dataset/clean_pieces/clean497.wav
#   inflating: content/dataset/clean_pieces/clean801.wav
#   inflating: content/dataset/clean_pieces/clean188.wav
#   inflating: content/dataset/clean_pieces/clean955.wav
#   inflating: content/dataset/clean_pieces/clean491.wav
#   inflating: content/dataset/clean_pieces/clean874.wav
#   inflating: content/dataset/clean_pieces/clean408.wav
#   inflating: content/dataset/clean_pieces/clean287.wav
#   inflating: content/dataset/clean_pieces/clean477.wav
#   inflating: content/dataset/clean_pieces/clean464.wav
#   inflating: content/dataset/clean_pieces/clean744.wav
#   inflating: content/dataset/clean_pieces/clean356.wav
#   inflating: content/dataset/clean_pieces/clean562.wav
#   inflating: content/dataset/clean_pieces/clean199.wav
#   inflating: content/dataset/clean_pieces/clean768.wav
#   inflating: content/dataset/clean_pieces/clean875.wav
#   inflating: content/dataset/clean_pieces/clean314.wav
#   inflating: content/dataset/clean_pieces/clean385.wav
#   inflating: content/dataset/clean_pieces/clean512.wav
#   inflating: content/dataset/clean_pieces/clean368.wav
#   inflating: content/dataset/clean_pieces/clean871.wav
#   inflating: content/dataset/clean_pieces/clean585.wav
#   inflating: content/dataset/clean_pieces/clean187.wav
#   inflating: content/dataset/clean_pieces/clean236.wav
#   inflating: content/dataset/clean_pieces/clean645.wav
#   inflating: content/dataset/clean_pieces/clean164.wav
#   inflating: content/dataset/clean_pieces/clean638.wav
#   inflating: content/dataset/clean_pieces/clean261.wav
#   inflating: content/dataset/clean_pieces/clean586.wav
#   inflating: content/dataset/clean_pieces/clean974.wav
#   inflating: content/dataset/clean_pieces/clean102.wav
#   inflating: content/dataset/clean_pieces/clean77.wav
#   inflating: content/dataset/clean_pieces/clean667.wav
#   inflating: content/dataset/clean_pieces/clean816.wav
#   inflating: content/dataset/clean_pieces/clean135.wav
#   inflating: content/dataset/clean_pieces/clean848.wav
#   inflating: content/dataset/clean_pieces/clean245.wav
#   inflating: content/dataset/clean_pieces/clean914.wav
#   inflating: content/dataset/clean_pieces/clean432.wav
#   inflating: content/dataset/clean_pieces/clean710.wav
#   inflating: content/dataset/clean_pieces/clean975.wav
#   inflating: content/dataset/clean_pieces/clean63.wav
#   inflating: content/dataset/clean_pieces/clean908.wav
#   inflating: content/dataset/clean_pieces/clean452.wav
#   inflating: content/dataset/clean_pieces/clean316.wav
#   inflating: content/dataset/clean_pieces/clean399.wav
#   inflating: content/dataset/clean_pieces/clean708.wav
#   inflating: content/dataset/clean_pieces/clean703.wav
#   inflating: content/dataset/clean_pieces/clean823.wav
#   inflating: content/dataset/clean_pieces/clean734.wav
#   inflating: content/dataset/clean_pieces/clean61.wav
#   inflating: content/dataset/clean_pieces/clean347.wav
#   inflating: content/dataset/clean_pieces/clean111.wav
#   inflating: content/dataset/clean_pieces/clean600.wav
#   inflating: content/dataset/clean_pieces/clean901.wav
#   inflating: content/dataset/clean_pieces/clean535.wav
#   inflating: content/dataset/clean_pieces/clean471.wav
#   inflating: content/dataset/clean_pieces/clean658.wav
#   inflating: content/dataset/clean_pieces/clean294.wav
#   inflating: content/dataset/clean_pieces/clean384.wav
#   inflating: content/dataset/clean_pieces/clean302.wav
#   inflating: content/dataset/clean_pieces/clean787.wav
#   inflating: content/dataset/clean_pieces/clean937.wav
#   inflating: content/dataset/clean_pieces/clean207.wav
#   inflating: content/dataset/clean_pieces/clean534.wav
#   inflating: content/dataset/clean_pieces/clean634.wav
#   inflating: content/dataset/clean_pieces/clean49.wav
#   inflating: content/dataset/clean_pieces/clean802.wav
#   inflating: content/dataset/clean_pieces/clean173.wav
#   inflating: content/dataset/clean_pieces/clean217.wav
#   inflating: content/dataset/clean_pieces/clean540.wav
#   inflating: content/dataset/clean_pieces/clean661.wav
#   inflating: content/dataset/clean_pieces/clean899.wav
#   inflating: content/dataset/clean_pieces/clean517.wav
#   inflating: content/dataset/clean_pieces/clean396.wav
#   inflating: content/dataset/clean_pieces/clean128.wav
#   inflating: content/dataset/clean_pieces/clean272.wav
#   inflating: content/dataset/clean_pieces/clean956.wav
#   inflating: content/dataset/clean_pieces/clean71.wav
#   inflating: content/dataset/clean_pieces/clean9.wav
#   inflating: content/dataset/clean_pieces/clean393.wav
#   inflating: content/dataset/clean_pieces/clean693.wav
#   inflating: content/dataset/clean_pieces/clean219.wav
#   inflating: content/dataset/clean_pieces/clean344.wav
#   inflating: content/dataset/clean_pieces/clean963.wav
#   inflating: content/dataset/clean_pieces/clean470.wav
#   inflating: content/dataset/clean_pieces/clean45.wav
#   inflating: content/dataset/clean_pieces/clean349.wav
#   inflating: content/dataset/clean_pieces/clean415.wav
#   inflating: content/dataset/clean_pieces/clean647.wav
#   inflating: content/dataset/clean_pieces/clean397.wav
#   inflating: content/dataset/clean_pieces/clean191.wav
#   inflating: content/dataset/clean_pieces/clean23.wav
#   inflating: content/dataset/clean_pieces/clean705.wav
#   inflating: content/dataset/clean_pieces/clean353.wav
#   inflating: content/dataset/clean_pieces/clean395.wav
#   inflating: content/dataset/clean_pieces/clean636.wav
#   inflating: content/dataset/clean_pieces/clean315.wav
#   inflating: content/dataset/clean_pieces/clean124.wav
#   inflating: content/dataset/clean_pieces/clean174.wav
#   inflating: content/dataset/clean_pieces/clean711.wav
#   inflating: content/dataset/clean_pieces/clean482.wav
#   inflating: content/dataset/clean_pieces/clean583.wav
#   inflating: content/dataset/clean_pieces/clean184.wav
#   inflating: content/dataset/clean_pieces/clean732.wav
#   inflating: content/dataset/clean_pieces/clean759.wav
#   inflating: content/dataset/clean_pieces/clean30.wav
#   inflating: content/dataset/clean_pieces/clean32.wav
#   inflating: content/dataset/clean_pieces/clean867.wav
#   inflating: content/dataset/clean_pieces/clean290.wav
#   inflating: content/dataset/clean_pieces/clean221.wav
#   inflating: content/dataset/clean_pieces/clean402.wav
#   inflating: content/dataset/clean_pieces/clean80.wav
#   inflating: content/dataset/clean_pieces/clean664.wav
#   inflating: content/dataset/clean_pieces/clean226.wav
#   inflating: content/dataset/clean_pieces/clean591.wav
#   inflating: content/dataset/clean_pieces/clean564.wav
#   inflating: content/dataset/clean_pieces/clean306.wav
#   inflating: content/dataset/clean_pieces/clean755.wav
#   inflating: content/dataset/clean_pieces/clean678.wav
#   inflating: content/dataset/clean_pieces/clean121.wav
#   inflating: content/dataset/clean_pieces/clean95.wav
#   inflating: content/dataset/clean_pieces/clean176.wav
#   inflating: content/dataset/clean_pieces/clean182.wav
#   inflating: content/dataset/clean_pieces/clean43.wav
#   inflating: content/dataset/clean_pieces/clean409.wav
#   inflating: content/dataset/clean_pieces/clean881.wav
#   inflating: content/dataset/clean_pieces/clean129.wav
#   inflating: content/dataset/clean_pieces/clean757.wav
#   inflating: content/dataset/clean_pieces/clean790.wav
#   inflating: content/dataset/clean_pieces/clean490.wav
#   inflating: content/dataset/clean_pieces/clean855.wav
#   inflating: content/dataset/clean_pieces/clean252.wav
#   inflating: content/dataset/clean_pieces/clean381.wav
#   inflating: content/dataset/clean_pieces/clean670.wav
#   inflating: content/dataset/clean_pieces/clean390.wav
#   inflating: content/dataset/clean_pieces/clean998.wav
#   inflating: content/dataset/clean_pieces/clean742.wav
#   inflating: content/dataset/clean_pieces/clean438.wav
#   inflating: content/dataset/clean_pieces/clean953.wav
#   inflating: content/dataset/clean_pieces/clean473.wav
#   inflating: content/dataset/clean_pieces/clean864.wav
#   inflating: content/dataset/clean_pieces/clean386.wav
#   inflating: content/dataset/clean_pieces/clean460.wav
#   inflating: content/dataset/clean_pieces/clean508.wav
#   inflating: content/dataset/clean_pieces/clean488.wav
#   inflating: content/dataset/clean_pieces/clean104.wav
#   inflating: content/dataset/clean_pieces/clean841.wav
#   inflating: content/dataset/clean_pieces/clean249.wav
#   inflating: content/dataset/clean_pieces/clean403.wav
#   inflating: content/dataset/clean_pieces/clean5.wav
#   inflating: content/dataset/clean_pieces/clean406.wav
#   inflating: content/dataset/clean_pieces/clean748.wav
#   inflating: content/dataset/clean_pieces/clean893.wav
#   inflating: content/dataset/clean_pieces/clean626.wav
#   inflating: content/dataset/clean_pieces/clean416.wav
#   inflating: content/dataset/clean_pieces/clean713.wav
#   inflating: content/dataset/clean_pieces/clean992.wav
#   inflating: content/dataset/clean_pieces/clean501.wav
#   inflating: content/dataset/clean_pieces/clean175.wav
#   inflating: content/dataset/clean_pieces/clean719.wav
#   inflating: content/dataset/clean_pieces/clean210.wav
#   inflating: content/dataset/clean_pieces/clean133.wav
#   inflating: content/dataset/clean_pieces/clean264.wav
#   inflating: content/dataset/clean_pieces/clean745.wav
#   inflating: content/dataset/clean_pieces/clean927.wav
#   inflating: content/dataset/clean_pieces/clean242.wav
#   inflating: content/dataset/clean_pieces/clean74.wav
#   inflating: content/dataset/clean_pieces/clean894.wav
#   inflating: content/dataset/clean_pieces/clean913.wav
#   inflating: content/dataset/clean_pieces/clean749.wav
#   inflating: content/dataset/clean_pieces/clean337.wav
#   inflating: content/dataset/clean_pieces/clean301.wav
#   inflating: content/dataset/clean_pieces/clean388.wav
#   inflating: content/dataset/clean_pieces/clean10.wav
#   inflating: content/dataset/clean_pieces/clean70.wav
#   inflating: content/dataset/clean_pieces/clean951.wav
#   inflating: content/dataset/clean_pieces/clean503.wav
#   inflating: content/dataset/clean_pieces/clean31.wav
#   inflating: content/dataset/clean_pieces/clean944.wav
#   inflating: content/dataset/clean_pieces/clean869.wav
#   inflating: content/dataset/clean_pieces/clean947.wav
#   inflating: content/dataset/clean_pieces/clean303.wav
#   inflating: content/dataset/clean_pieces/clean50.wav
#   inflating: content/dataset/clean_pieces/clean335.wav
#   inflating: content/dataset/clean_pieces/clean554.wav
#   inflating: content/dataset/clean_pieces/clean431.wav
#   inflating: content/dataset/clean_pieces/clean835.wav
#   inflating: content/dataset/clean_pieces/clean198.wav
#   inflating: content/dataset/clean_pieces/clean186.wav
#   inflating: content/dataset/clean_pieces/clean976.wav
#   inflating: content/dataset/clean_pieces/clean279.wav
#   inflating: content/dataset/clean_pieces/clean666.wav
#   inflating: content/dataset/clean_pieces/clean59.wav
#   inflating: content/dataset/clean_pieces/clean537.wav
#   inflating: content/dataset/clean_pieces/clean251.wav
#   inflating: content/dataset/clean_pieces/clean907.wav
#   inflating: content/dataset/clean_pieces/clean459.wav
#   inflating: content/dataset/clean_pieces/clean424.wav
#   inflating: content/dataset/clean_pieces/clean7.wav
#   inflating: content/dataset/clean_pieces/clean885.wav
#   inflating: content/dataset/clean_pieces/clean457.wav
#   inflating: content/dataset/clean_pieces/clean203.wav
#   inflating: content/dataset/clean_pieces/clean910.wav
#   inflating: content/dataset/clean_pieces/clean68.wav
#   inflating: content/dataset/clean_pieces/clean213.wav
#   inflating: content/dataset/clean_pieces/clean655.wav
#   inflating: content/dataset/clean_pieces/clean577.wav
#   inflating: content/dataset/clean_pieces/clean772.wav
#   inflating: content/dataset/clean_pieces/clean192.wav
#   inflating: content/dataset/clean_pieces/clean629.wav
#   inflating: content/dataset/clean_pieces/clean797.wav
#   inflating: content/dataset/clean_pieces/clean880.wav
#   inflating: content/dataset/clean_pieces/clean483.wav
#   inflating: content/dataset/clean_pieces/clean254.wav
#   inflating: content/dataset/clean_pieces/clean657.wav
#   inflating: content/dataset/clean_pieces/clean721.wav
#   inflating: content/dataset/clean_pieces/clean348.wav
#   inflating: content/dataset/clean_pieces/clean107.wav
#   inflating: content/dataset/clean_pieces/clean19.wav
#   inflating: content/dataset/clean_pieces/clean936.wav
#   inflating: content/dataset/clean_pieces/clean939.wav
#   inflating: content/dataset/clean_pieces/clean796.wav
#   inflating: content/dataset/clean_pieces/clean777.wav
#   inflating: content/dataset/clean_pieces/clean578.wav
#   inflating: content/dataset/clean_pieces/clean228.wav
#   inflating: content/dataset/clean_pieces/clean427.wav
#   inflating: content/dataset/clean_pieces/clean566.wav
#   inflating: content/dataset/clean_pieces/clean911.wav
#   inflating: content/dataset/clean_pieces/clean352.wav
#   inflating: content/dataset/clean_pieces/clean978.wav
#   inflating: content/dataset/clean_pieces/clean642.wav
#   inflating: content/dataset/clean_pieces/clean912.wav
#   inflating: content/dataset/clean_pieces/clean754.wav
#   inflating: content/dataset/clean_pieces/clean151.wav
#   inflating: content/dataset/clean_pieces/clean960.wav
#   inflating: content/dataset/clean_pieces/clean25.wav
#   inflating: content/dataset/clean_pieces/clean809.wav
#   inflating: content/dataset/clean_pieces/clean683.wav
#   inflating: content/dataset/clean_pieces/clean215.wav

# %% [markdown]
# #Load the Data

# %%
clean_sounds = sorted(glob.glob('/content/content/dataset/clean_pieces/*'))
noisy_sounds = sorted(glob.glob('/content/content/dataset/noisy_pieces/*'))

clean_sounds_list,_ = tf.audio.decode_wav(tf.io.read_file(clean_sounds[0]),desired_channels=1)
for i in tqdm(clean_sounds[1:]):
  so,_ = tf.audio.decode_wav(tf.io.read_file(i),desired_channels=1)
  clean_sounds_list = tf.concat((clean_sounds_list,so),0)

noisy_sounds_list,_ = tf.audio.decode_wav(tf.io.read_file(noisy_sounds[0]),desired_channels=1)
for i in tqdm(noisy_sounds[1:]):
  so,_ = tf.audio.decode_wav(tf.io.read_file(i),desired_channels=1)
  noisy_sounds_list = tf.concat((noisy_sounds_list,so),0)

clean_sounds_list.shape,noisy_sounds_list.shape
# Out:
#   0%|          | 0/999 [00:00<?, ?it/s]
#   0%|          | 0/999 [00:00<?, ?it/s]
# (TensorShape([198450000, 1]), TensorShape([198450000, 1]))

# %%
batching_size = 12000

clean_train,noisy_train = [],[]

for i in tqdm(range(0,clean_sounds_list.shape[0]-batching_size,batching_size)):
  clean_train.append(clean_sounds_list[i:i+batching_size])
  noisy_train.append(noisy_sounds_list[i:i+batching_size])

clean_train = tf.stack(clean_train)
noisy_train = tf.stack(noisy_train)

clean_train.shape,noisy_train.shape
# Out:
#   0%|          | 0/16537 [00:00<?, ?it/s]
# (TensorShape([16537, 12000, 1]), TensorShape([16537, 12000, 1]))

# %% [markdown]
# # Create a tf.data.Dataset

# %%
def get_dataset(x_train,y_train):
  dataset = tf.data.Dataset.from_tensor_slices((x_train,y_train))
  dataset = dataset.shuffle(100).batch(64,drop_remainder=True)
  return dataset

# %%
train_dataset = get_dataset(noisy_train[:40000],clean_train[:40000])
test_dataset = get_dataset(noisy_train[40000:],clean_train[40000:])

# %% [markdown]
# #Reviewing Sample Waveform

# %%
librosa.display.waveplot(np.squeeze(clean_train[5].numpy(),axis=-1))
plt.show()
librosa.display.waveplot(np.squeeze(noisy_train[5].numpy(),axis=-1))
plt.show()

# %% [markdown]
# #Creating the Model

# %%
inp = Input(shape=(batching_size,1))
c1 = Conv1D(2,32,2,'same',activation='relu')(inp)
c2 = Conv1D(4,32,2,'same',activation='relu')(c1)
c3 = Conv1D(8,32,2,'same',activation='relu')(c2)
c4 = Conv1D(16,32,2,'same',activation='relu')(c3)
c5 = Conv1D(32,32,2,'same',activation='relu')(c4)

dc1 = Conv1DTranspose(32,32,1,padding='same')(c5)
conc = Concatenate()([c5,dc1])
dc2 = Conv1DTranspose(16,32,2,padding='same')(conc)
conc = Concatenate()([c4,dc2])
dc3 = Conv1DTranspose(8,32,2,padding='same')(conc)
conc = Concatenate()([c3,dc3])
dc4 = Conv1DTranspose(4,32,2,padding='same')(conc)
conc = Concatenate()([c2,dc4])
dc5 = Conv1DTranspose(2,32,2,padding='same')(conc)
conc = Concatenate()([c1,dc5])
dc6 = Conv1DTranspose(1,32,2,padding='same')(conc)
conc = Concatenate()([inp,dc6])
dc7 = Conv1DTranspose(1,32,1,padding='same',activation='linear')(conc)
model = tf.keras.models.Model(inp,dc7)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 12000, 1)]   0           []
#
#  conv1d (Conv1D)                (None, 6000, 2)      66          ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 3000, 4)      260         ['conv1d[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 1500, 8)      1032        ['conv1d_1[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 750, 16)      4112        ['conv1d_2[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 375, 32)      16416       ['conv1d_3[0][0]']
#
#  conv1d_transpose (Conv1DTransp  (None, 375, 32)     32800       ['conv1d_4[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 375, 64)      0           ['conv1d_4[0][0]',
#                                                                   'conv1d_transpose[0][0]']
#
#  conv1d_transpose_1 (Conv1DTran  (None, 750, 16)     32784       ['concatenate[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 750, 32)      0           ['conv1d_3[0][0]',
#                                                                   'conv1d_transpose_1[0][0]']
#
#  conv1d_transpose_2 (Conv1DTran  (None, 1500, 8)     8200        ['concatenate_1[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 1500, 16)     0           ['conv1d_2[0][0]',
#                                                                   'conv1d_transpose_2[0][0]']
#
#  conv1d_transpose_3 (Conv1DTran  (None, 3000, 4)     2052        ['concatenate_2[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (None, 3000, 8)      0           ['conv1d_1[0][0]',
#                                                                   'conv1d_transpose_3[0][0]']
#
#  conv1d_transpose_4 (Conv1DTran  (None, 6000, 2)     514         ['concatenate_3[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 6000, 4)      0           ['conv1d[0][0]',
#                                                                   'conv1d_transpose_4[0][0]']
#
#  conv1d_transpose_5 (Conv1DTran  (None, 12000, 1)    129         ['concatenate_4[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 12000, 2)     0           ['input_1[0][0]',
#                                                                   'conv1d_transpose_5[0][0]']
#
#  conv1d_transpose_6 (Conv1DTran  (None, 12000, 1)    65          ['concatenate_5[0][0]']
#  spose)
#
# ==================================================================================================
# Total params: 98,430
# Trainable params: 98,430
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model,show_shapes=True,show_layer_names=False)

# %% [markdown]
# #Training

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(0.002),loss=tf.keras.losses.MeanAbsoluteError())
history = model.fit(train_dataset,epochs=20)
# Out:
# Epoch 1/20
# 258/258 [==============================] - 21s 32ms/step - loss: 0.0444
# Epoch 2/20
# 258/258 [==============================] - 10s 38ms/step - loss: 0.0359
# Epoch 3/20
# 258/258 [==============================] - 12s 45ms/step - loss: 0.0326
# Epoch 4/20
# 258/258 [==============================] - 12s 45ms/step - loss: 0.0316
# Epoch 5/20
# 258/258 [==============================] - 9s 36ms/step - loss: 0.0294
# Epoch 6/20
# 258/258 [==============================] - 9s 36ms/step - loss: 0.0292
# Epoch 7/20
# 258/258 [==============================] - 10s 37ms/step - loss: 0.0273
# Epoch 8/20
# 258/258 [==============================] - 10s 37ms/step - loss: 0.0272
# Epoch 9/20
# 258/258 [==============================] - 10s 37ms/step - loss: 0.0266
# Epoch 10/20
# 258/258 [==============================] - 10s 40ms/step - loss: 0.0260
# Epoch 11/20
# 258/258 [==============================] - 10s 39ms/step - loss: 0.0257
# Epoch 12/20
# 258/258 [==============================] - 10s 39ms/step - loss: 0.0250
# Epoch 13/20
# 258/258 [==============================] - 10s 40ms/step - loss: 0.0243
# Epoch 14/20
# 258/258 [==============================] - 10s 40ms/step - loss: 0.0242
# Epoch 15/20
# 258/258 [==============================] - 10s 40ms/step - loss: 0.0237
# Epoch 16/20
# 258/258 [==============================] - 10s 40ms/step - loss: 0.0239
# Epoch 17/20
# 258/258 [==============================] - 10s 39ms/step - loss: 0.0237
# Epoch 18/20
# 258/258 [==============================] - 10s 39ms/step - loss: 0.0234
# Epoch 19/20
# 258/258 [==============================] - 9s 36ms/step - loss: 0.0230
# Epoch 20/20
# 258/258 [==============================] - 9s 36ms/step - loss: 0.0227

# %% [markdown]
# #Testing Samples

# %%
from IPython.display import Audio
Audio(np.squeeze(noisy_train[10000].numpy()),rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(tf.squeeze(model.predict(tf.expand_dims(tf.expand_dims(noisy_train[10000],-1),0))),rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
temp = model.predict(tf.expand_dims(tf.expand_dims(noisy_train[22],-1),0))
for i in noisy_train[23:38]:
  pred = model.predict(tf.expand_dims(tf.expand_dims(i,-1),0))
  temp = np.concatenate([temp,pred],0)

# %%
temp.shape
# Out:
# (16, 12000, 1)

# %%
arr = np.reshape(temp,(192000,1))

# %%
Audio(tf.squeeze(arr),rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fav, sample_rate = tf.audio.decode_wav(tf.io.read_file(noisy_sounds[1]),desired_channels=1)

# %%
fav.shape
# Out:
# TensorShape([198450, 1])

# %%
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

# %%
arr = []
for i in tqdm(range(0,fav.shape[0]-batching_size,batching_size)):
  arr.append(fav[i:i+batching_size])

arr = tf.stack(arr)

arr.shape
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# TensorShape([16, 12000, 1])

# %%
temp = model.predict(tf.expand_dims(tf.expand_dims(arr[1],-1),0))
for i in arr[1:]:
  pred = model.predict(tf.expand_dims(tf.expand_dims(i,-1),0))
  temp = np.concatenate([temp,pred],0)

# %%
arr = np.reshape(temp,(192000,1))

# %%
Audio(tf.squeeze(arr),rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
noisy, sample_rate = tf.audio.decode_wav(tf.io.read_file(noisy_sounds[1]),desired_channels=1)

# %%
Audio(tf.squeeze(noisy),rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
clean, sample_rate = tf.audio.decode_wav(tf.io.read_file(clean_sounds[1]),desired_channels=1)

# %%
Audio(tf.squeeze(clean),rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
model.evaluate(test_dataset)

# %%
model.save('NoiseSuppressionModel.h5')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r "NoiseSuppressionModel.h5" "/content/drive/MyDrive/NoiseSuppressionModel.h5"

# %% [markdown]
# # Inference
#
# Handling different sized audio inputs can be solved by overlapping prediction frames and removing the intersection part from the final waveform

# %%
def get_audio(path):
  audio,_ = tf.audio.decode_wav(tf.io.read_file(path),1)
  return audio

# %%
def inference_preprocess(path):
  audio = get_audio(path)
  audio_len = audio.shape[0]
  batches = []
  for i in range(0,audio_len-batching_size,batching_size):
    batches.append(audio[i:i+batching_size])

  batches.append(audio[-batching_size:])
  diff = audio_len - (i + batching_size)
  return tf.stack(batches), diff

# %%
def predict(path):
  test_data,diff = inference_preprocess(path)
  predictions = model.predict(test_data)
  final_op = tf.reshape(predictions[:-1],((predictions.shape[0]-1)*predictions.shape[1],1))
  final_op = tf.concat((final_op,predictions[-1][-diff:]),axis=0)
  return final_op

# %%
Audio(np.squeeze(get_audio(noisy_sounds[4]).numpy(),-1),rate=16000)

# %%
Audio(tf.squeeze(predict(noisy_sounds[4])),rate=16000)

# %%
# %%timeit
tf.squeeze(predict(noisy_sounds[3]))

# %%
librosa.display.waveplot(np.squeeze(get_audio(noisy_sounds[4]).numpy(),-1))
librosa.display.waveplot(np.squeeze(predict(noisy_sounds[4])))

# %% [markdown]
# #Quantization and TFLite Conversion

# %%
lite_model = tf.lite.TFLiteConverter.from_keras_model(model)
lite_model.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model_quant = lite_model.convert()

# %%
with open('TFLiteModel.tflite','wb') as f:
  f.write(tflite_model_quant)

# %% [markdown]
# #TFLite Inference

# %%
interpreter = tf.lite.Interpreter(model_path='/content/TFLiteModel.tflite')
interpreter.allocate_tensors()

# %%
def predict_tflite(path):
  test_audio,diff = inference_preprocess(path)
  input_index = interpreter.get_input_details()[0]["index"]
  output_index = interpreter.get_output_details()[0]["index"]

  preds = []
  for i in test_audio:
    interpreter.set_tensor(input_index, tf.expand_dims(i,0))
    interpreter.invoke()
    predictions = interpreter.get_tensor(output_index)
    preds.append(predictions)

  predictions = tf.squeeze(tf.stack(preds,axis=1))
  final_op = tf.reshape(predictions[:-1],((predictions.shape[0]-1)*predictions.shape[1],1))
  final_op = tf.concat((tf.squeeze(final_op),predictions[-1][-diff:]),axis=0)
  return final_op

# %%
# Original Noisy Audio
Audio(np.squeeze(get_audio(noisy_sounds[4]).numpy(),-1),rate=16000)

# %%
# Clean Audio
Audio(np.squeeze(get_audio(clean_sounds[4]).numpy(),-1),rate=16000)

# %%
# Output Audio
Audio(predict_tflite(noisy_sounds[4]),rate=16000)

# %%
# %%timeit
predict_tflite(noisy_sounds[3])

# %%
librosa.display.waveplot(np.squeeze(get_audio(noisy_sounds[4]).numpy(),-1))
librosa.display.waveplot(predict_tflite(noisy_sounds[4]).numpy())
